# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline

import os, sys, pickle, copy, pygmt, operator

import pandas as pd


from pathlib import Path
from time import sleep
from tqdm import tqdm, tqdm_notebook

import numpy as np


from scipy import stats

import xarray as xr
from matplotlib import pyplot as plt
import matplotlib.gridspec as gridspec

from sklearn.ensemble import RandomForestRegressor

import pyproj as proj


import seaborn as sns; sns.set()
sns.set_theme(style="white")

from sklearn.pipeline import Pipeline
from sklearn.ensemble import RandomForestRegressor
from sklearn.preprocessing import OrdinalEncoder , PowerTransformer
from sklearn.compose import make_column_selector as selector
from sklearn.compose import ColumnTransformer, TransformedTargetRegressor


from sklearn import tree


from sklearn.metrics import make_scorer, explained_variance_score, mean_absolute_error, mean_squared_error, \
r2_score, max_error, median_absolute_error, mean_absolute_percentage_error

# %%
# constanst
crs_to='epsg:4326'
crs_from='epsg:4326'
projection = 'M5.4i'
#parent directory

DIR = Path().resolve() 


plt_params = {
    "axes.titlesize" : 25, # main
    "axes.labelsize" : 20,  # labels
    "axes.edgecolor" : "black", 
    "axes.linewidth" : 1, 
    'xtick.labelsize': 17, # ticks
    'ytick.labelsize': 17,
    'legend.fontsize': 17,
}

plt.rcParams.update(plt_params)


# We can exclude Arctic ocean and Antarctica, as there are no HF measurements to use
world_lon_min, world_lon_max, world_lat_min, world_lat_max  = -180, 180, -60, 80

# map extents of Africa
afr_lon_min, afr_lon_max, afr_lat_min, afr_lat_max =  -20, 52, -37 , 38  


region_afr = [afr_lon_min, afr_lon_max, afr_lat_min, afr_lat_max]
region_world = [world_lon_min, world_lon_max, world_lat_min, world_lat_max]

# %%
class SeabornFig2Grid():

    def __init__(self, seaborngrid, fig,  subplot_spec):
        self.fig = fig
        self.sg = seaborngrid
        self.subplot = subplot_spec
        if isinstance(self.sg, sns.axisgrid.FacetGrid) or \
            isinstance(self.sg, sns.axisgrid.PairGrid):
            self._movegrid()
        elif isinstance(self.sg, sns.axisgrid.JointGrid):
            self._movejointgrid()
        self._finalize()

    def _movegrid(self):
        """ Move PairGrid or Facetgrid """
        self._resize()
        n = self.sg.axes.shape[0]
        m = self.sg.axes.shape[1]
        self.subgrid = gridspec.GridSpecFromSubplotSpec(n,m, subplot_spec=self.subplot)
        for i in range(n):
            for j in range(m):
                self._moveaxes(self.sg.axes[i,j], self.subgrid[i,j])

    def _movejointgrid(self):
        """ Move Jointgrid """
        h= self.sg.ax_joint.get_position().height
        h2= self.sg.ax_marg_x.get_position().height
        r = int(np.round(h/h2))
        self._resize()
        self.subgrid = gridspec.GridSpecFromSubplotSpec(r+1,r+1, subplot_spec=self.subplot)

        self._moveaxes(self.sg.ax_joint, self.subgrid[1:, :-1])
        self._moveaxes(self.sg.ax_marg_x, self.subgrid[0, :-1])
        self._moveaxes(self.sg.ax_marg_y, self.subgrid[1:, -1])

    def _moveaxes(self, ax, gs):
        #https://stackoverflow.com/a/46906599/4124317
        ax.remove()
        ax.figure=self.fig
        self.fig.axes.append(ax)
        self.fig.add_axes(ax)
        ax._subplotspec = gs
        ax.set_position(gs.get_position(self.fig))
        ax.set_subplotspec(gs)

    def _finalize(self):
        plt.close(self.sg.fig)
        self.fig.canvas.mpl_connect("resize_event", self._resize)
        self.fig.canvas.draw()

    def _resize(self, evt=None):
        self.sg.fig.set_size_inches(self.fig.get_size_inches())

# %%
def concordance_correlation_coefficient(y_true, y_pred):
    """Concordance correlation coefficient."""
    # Remove NaNs
    df = pd.DataFrame({
        'y_true': y_true,
        'y_pred': y_pred
    })
    df = df.dropna()
    y_true = df['y_true']
    y_pred = df['y_pred']
    # Pearson product-moment correlation coefficients
    cor = np.corrcoef(y_true, y_pred)[0][1]
    # Mean
    mean_true = np.mean(y_true)
    mean_pred = np.mean(y_pred)
    # Variance
    var_true = np.var(y_true)
    var_pred = np.var(y_pred)
    # Standard deviation
    sd_true = np.std(y_true)
    sd_pred = np.std(y_pred)
    # Calculate CCC
    numerator = 2 * cor * sd_true * sd_pred
    denominator = var_true + var_pred + (mean_true - mean_pred)**2
    return numerator / denominator

# %%
ds_afr_rab = xr.load_dataset(DIR/'Grids'/'Outputs'/"ds_afr_rfr_rab.nc")
ds_afr_ra = xr.load_dataset(DIR/'Grids'/'Outputs'/"ds_afr_rfr_ra.nc")

#ds_afr = xr.load_dataset(DIR/'Grids'/'Inputs'/"ds_afr.nc")

# %%
obs = pd.DataFrame()


obs["OBS_REF"] = ["CTD" ,  "SI","LAB", "MOHO",
            "SV","PV", 
            "GEOID","FA","DEM","BG", "EMAG2_CLASS",
                   "RHO_L", "RHO_C", 
                  "VOLC_DIST_W", "REG", "GLIM"]

obs["OBS_AFR"] = ["CTD" ,  "SI","LAB", "MOHO",
            "SV_Velocity","PV_Velocity", 
            "GEOID","FA","DEM","BG", "EMAG2",
                   "RHO_L", "RHO_C", 
                  "VOLC_DIST", "REG", "GLIM"]
  
     
# Labels for plots etc


# Labels for plots etc
obs["LABELS_gmt"] = ["CTD",  "Shape index", "LAB", "Moho", 
                "S@_v@ 150km", "P@_v@ 150km", 
                "Geoid", "Free air", "DEM", "Bouguer", "Mag.", 
                "Lith. rho", "Crust rho",  
                 "Volcano", "REG", "GliM", ]  


obs["LABELS"] = ["CTD",  "Shape index", "LAB", "Moho", 
                "$S_v$ @150km", "$P_v$ @150km", 
                "Geoid", "Free air", "DEM", "Bouguer", "Mag.", 
                "Lith. ρ", "Crust ρ",  
                 "Volcano", "REG", "GliM", ]
    
# "vp/vs"
# Units to display in plots etc
obs["UNITS"] = ["km",  "si", "km", "km",
             "$\delta$$S_v$ %","$\delta$$P_v$ %", 
             "m", "mGal", "m", "mGal",  "f(nT)", 
                 "kg/m$^3$", "kg/m$^3$",
                "km",  "class", "class"]



obs["UNITS_gmt"] = ["km",  "si", "km", "km",
             "km/s","km/s", 
             "m", "mGal", "m", "mGal",  "f(nT)", 
                 "kg/m@+3@+", "kg/m@+3@+",
                "km",  "class", "class"]
        
# Range of colormap for plots. Similar data are placed in same ranges for consistancy
obs["V_RANGE"] = [(0,50), (-1,1),(0,300),(15,60),
              (-0.075,0.075), (-0.02,0.02), 
              (-45,45), (-100,100) , (-2200, 2200),(-100,100),  (-0.4, 0.4), 
                   (3260, 3360), (2650, 2950),
                  (0,1), (1,6),(1,16),]


    
obs["V_RANGE_AFR"] = [(0,50), (-1,1),(50,250),(20,50),
          (-0.075,0.075), (-0.02,0.02), 
          (-45,45), (-100,100) , (-2200, 2200),(-100,100),  (-200, 200), 
               (3260, 3360), (2650, 2950),
              (0,100), (1,6),(1,15),]


obs["CMAPS"] = ["batlow",  "broc", "bamako", "batlow", 
             "roma","roma", 
             "bamako", "broc", "bukavu", "broc", "batlow",            
                "batlow", "batlow",
               "bamako",  "batlowS","categorical", ]

obs["CMAPS"] = ["SCM/bamako",  "SCM/broc", "SCM/bamako", "SCM/bamako", 
             "SCM/roma","SCM/roma", 
             "SCM/bamako", "SCM/broc", "SCM/oleron", "SCM/broc", "SCM/bilbao",            
                "SCM/batlow", "SCM/batlow",
               "SCM/broc",  "gmt/categorical","gmt/categorical", ]

new_index = [0,1,2,3,4,5,6,8,7,9,10,11,12,13,14,15]

#new_index = [4,3,15,6,7,0, 14, 10,16, 8, 9,2, 13, 12, 8, 11, ]

obs = obs.reindex(new_index)

#obs.index = np.arange(0,len(obs))

pd.options.display.width = 370
pd.options.display.max_colwidth = 16




obs_dict = obs.to_dict(orient='records')

obs.set_index(['OBS_REF'], inplace=True)



obs
# Out:
#                  OBS_AFR   LABELS_gmt        LABELS            UNITS  UNITS_gmt          V_RANGE      V_RANGE_AFR            CMAPS
# OBS_REF
# CTD                  CTD          CTD           CTD               km         km          (0, 50)          (0, 50)       SCM/bamako
# SI                    SI  Shape index   Shape index               si         si          (-1, 1)          (-1, 1)         SCM/broc
# LAB                  LAB          LAB           LAB               km         km         (0, 300)        (50, 250)       SCM/bamako
# MOHO                MOHO         Moho          Moho               km         km         (15, 60)         (20, 50)       SCM/bamako
# SV           SV_Velocity  S@_v@ 150km  $S_v$ @150km  $\delta$$S_v$ %       km/s  (-0.075, 0.075)  (-0.075, 0.075)         SCM/roma
# PV           PV_Velocity  P@_v@ 150km  $P_v$ @150km  $\delta$$P_v$ %       km/s    (-0.02, 0.02)    (-0.02, 0.02)         SCM/roma
# GEOID              GEOID        Geoid         Geoid                m          m        (-45, 45)        (-45, 45)       SCM/bamako
# DEM                  DEM          DEM           DEM                m          m    (-2200, 2200)    (-2200, 2200)       SCM/oleron
# FA                    FA     Free air      Free air             mGal       mGal      (-100, 100)      (-100, 100)         SCM/broc
# BG                    BG      Bouguer       Bouguer             mGal       mGal      (-100, 100)      (-100, 100)         SCM/broc
# EMAG2_CLASS        EMAG2         Mag.          Mag.            f(nT)      f(nT)      (-0.4, 0.4)      (-200, 200)       SCM/bilbao
# RHO_L              RHO_L    Lith. rho       Lith. ρ         kg/m$^3$  kg/m@+3@+     (3260, 3360)     (3260, 3360)       SCM/batlow
# RHO_C              RHO_C    Crust rho       Crust ρ         kg/m$^3$  kg/m@+3@+     (2650, 2950)     (2650, 2950)       SCM/batlow
# VOLC_DIST_W    VOLC_DIST      Volcano       Volcano               km         km           (0, 1)         (0, 100)         SCM/broc
# REG                  REG          REG           REG            class      class           (1, 6)           (1, 6)  gmt/categorical
# GLIM                GLIM         GliM          GliM            class      class          (1, 16)          (1, 15)  gmt/categorical

# %%
target = 'GHF'
coord = ['lon', 'lat']
grid_index_world = 'grid_index_world'
grid_index_afr ='grid_index_afr'

hq_lower_bound = 10
hq_upper_bound = 200


#######

features_ex = []
features_ghf = []



features = obs.index.to_list()



in_features = set(features)

features_ex = copy.deepcopy(features)
features_ex.extend(coord)
features_ex.append(grid_index_world)
features_ex.append(grid_index_afr)

features_ex.append(target)

features_ghf = copy.deepcopy(features)
features_ghf.append(target)


features_ex
# Out:
# ['CTD',
#  'SI',
#  'LAB',
#  'MOHO',
#  'SV',
#  'PV',
#  'GEOID',
#  'DEM',
#  'FA',
#  'BG',
#  'EMAG2_CLASS',
#  'RHO_L',
#  'RHO_C',
#  'VOLC_DIST_W',
#  'REG',
#  'GLIM',
#  'lon',
#  'lat',
#  'grid_index_world',
#  'grid_index_afr',
#  'GHF']

# %%
Afr_OD_ra_f =  DIR/'Dataset'/'Preprocessed'/'Afr_OD_ra.csv'
Afr_OD_ra = pd.read_csv(Afr_OD_ra_f, sep='\t')

Afr_OD_rab_f =  DIR/'Dataset'/'Preprocessed'/'Afr_OD_rab.csv'
Afr_OD_rab = pd.read_csv(Afr_OD_rab_f, sep='\t')



#######

Afr_NOD_ra_f =  DIR/'Dataset'/'Preprocessed'/'Afr_NOD_ra.csv'
Afr_NOD_ra = pd.read_csv(Afr_NOD_ra_f,  sep='\t')

Afr_NOD_rab_f =  DIR/'Dataset'/'Preprocessed'/'Afr_NOD_rab.csv'
Afr_NOD_rab = pd.read_csv(Afr_NOD_rab_f,  sep='\t')

#######

Afr_NOD_ra_f =  DIR/'Dataset'/'Preprocessed'/'Afr_NOD_ra.csv'
Afr_NOD_ra = pd.read_csv(Afr_NOD_ra_f,  sep='\t')

Afr_NOD_rab_f =  DIR/'Dataset'/'Preprocessed'/'Afr_NOD_rab.csv'
Afr_NOD_rab = pd.read_csv(Afr_NOD_rab_f,  sep='\t')


######

Afr_int_ra_f =  DIR/'Dataset'/'Preprocessed'/'Afr_int_ra.csv'
Afr_int_ra = pd.read_csv(Afr_int_ra_f,  sep='\t')

Afr_int_rab_f =  DIR/'Dataset'/'Preprocessed'/'Afr_int_rab.csv'
Afr_int_rab = pd.read_csv(Afr_int_rab_f,  sep='\t')



###



W_OD_rab_f =  DIR/'Dataset'/'Preprocessed'/'W_OD_rab.csv'
W_OD_rab = pd.read_csv(W_OD_rab_f,  sep='\t')




Afr_OD_rab
# Out:
#       index_OD        CTD         LAB        SI       MOHO        SV        PV    DEM      GEOID  EMAG2_CLASS  ...          BG        RHO_L        RHO_C  VOLC_DIST_W  REG  GLIM      lon      lat  grid_index_afr   GHF
# 0            0  22.781880  112.389842  0.920882  29.965704  0.008493 -0.007649  -21.0  28.723169    -0.030117  ...  101.051505  3334.963780  2789.984860          0.0    6     3 -17.4500  14.7500           14591  66.8
# 1            1  22.781880  112.389842  0.920882  29.965704  0.008493 -0.007649  -21.0  28.723169    -0.030117  ...  101.051505  3334.963780  2789.984860          0.0    6     3 -17.4333  14.6833           14591  81.0
# 2            2  22.781880  112.389842  0.920882  29.965704  0.008493 -0.007649  -21.0  28.723169    -0.030117  ...  101.051505  3334.963780  2789.984860          0.0    6     3 -17.4333  14.7167           14591  73.2
# 3            3  22.781880  112.389842  0.920882  29.965704  0.008493 -0.007649  -21.0  28.723169    -0.030117  ...  101.051505  3334.963780  2789.984860          0.0    6     3 -17.4333  14.7333           14591  78.5
# 4            4  22.781880  112.389842  0.920882  29.965704  0.008493 -0.007649  -21.0  28.723169    -0.030117  ...  101.051505  3334.963780  2789.984860          0.0    6     3 -17.4167  14.7000           14591  67.7
# ...        ...        ...         ...       ...        ...       ...       ...    ...        ...          ...  ...         ...          ...          ...          ...  ...   ...      ...      ...             ...   ...
# 1715      1749  26.716814  178.464848 -0.838243  46.732259  0.070477  0.002988  229.0  -6.564284    -0.034223  ... -129.550135  3314.655684  2785.383456          0.0    1     6  49.3333  32.0000           19585  27.0
# 1716      1750  26.716814  178.464848 -0.838243  46.732259  0.070477  0.002988  229.0  -6.564284    -0.034223  ... -129.550135  3314.655684  2785.383456          0.0    1     6  49.3333  32.0000           19585  33.0
# 1717      1752  21.927017   81.183208 -0.289963  28.776219  0.030870 -0.010484  434.0 -34.326390     0.061970  ...   -2.090171  3301.742236  2812.574216          0.0    2     6  50.5167   9.5500           13295  59.0
# 1718      1753  21.927017   81.183208 -0.289963  28.776219  0.030870 -0.010484  434.0 -34.326390     0.061970  ...   -2.090171  3301.742236  2812.574216          0.0    2     6  50.6667   9.4167           13295  59.0
# 1719      1755  34.766143   92.887351  0.554952  45.259010  0.008960 -0.001665  989.0   4.186924    -0.104099  ... -107.659289  3268.584560  2748.257073          0.0    3     6  51.6167  35.6667           20590  88.0
#
# [1720 rows x 21 columns]

# %%
# decide upon resolution
# dataframe
Afr_OD_rab = Afr_OD_rab
Afr_OD_ra = Afr_OD_ra

Afr_NOD_rab = Afr_NOD_rab
Afr_NOD_ra = Afr_NOD_ra

# output grid
ds_afr_rab = ds_afr_rab
ds_afr_ra = ds_afr_ra

spacing = 0.5

# %% [markdown]
# # Tree visiualization

# %%
RANDOM_STATE=42



X_Afr = Afr_OD_rab[features]
y_Afr = Afr_OD_rab[target]



bs_rfr_hyp = pd.read_csv(DIR /'Hyperparameters'/f'BS_hyperparameter.csv' , sep='\t')


best_params = bs_rfr_hyp.to_dict('r')[0]

#####visulaize

numeric_transformer = PowerTransformer(method='yeo-johnson', standardize=True)
categorical_transformer = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

preprocessor = ColumnTransformer(
transformers=[
       ("num", numeric_transformer, selector(dtype_exclude="category")),
       ("cat", categorical_transformer, selector(dtype_include="category")),
], 
#remainder='passthrough', verbose_feature_names_out=False
)


regressor = RandomForestRegressor(random_state=RANDOM_STATE)


steps=[("preprocessor", preprocessor), 
   #("regressor", regressor), 
   ('ttr', TransformedTargetRegressor(regressor=regressor, transformer=numeric_transformer))
  ]

# Initialize Pipeline object
pipeline = Pipeline(steps=steps)

pipeline.set_params(**best_params)


pipeline.fit(X_Afr,y_Afr)

pipeline.get_params()

rf =  pipeline['ttr'].regressor_

fn= ['CTD',
 'SI',
 'LAB',
 'MOHO',
 'SV',
 'PV',
 'GEOID',
 'FA',
 'DEM',
 'BG',
 'EMAG2',
 'RHO_L',
 'RHO_C',
 'VOLC_D',
 'REG',
 'GLIM']

fig, axes = plt.subplots(figsize = (20,20) )


tree.plot_tree(rf.estimators_[100],
               feature_names = fn, 
               class_names=target,
               max_depth=2,
               fontsize=21,
               filled = True);


#fig.savefig(dir_p/ 'fig'/'presentation'/"fig_3.JPEG", bbox_inches='tight', dpi=300 )

# %% [markdown]
# # Visualiazation

# %% [markdown]
# # AFR

# %%
best_n_features = 'RFE_11'

labels = ['RFE_16', 'RFE_15', 'RFE_14', 'RFE_13', 'RFE_12', 'RFE_11', 'RFE_10', 'RFE_09', 'RFE_08', 'RFE_07', 
    'RFE_06', 'RFE_05', 'RFE_04', 
]

'''
# max min across all features
ds_afr_rab['max'] = ds_afr_rab[labels].to_array().max(axis=0) 
ds_afr_ra['max'] =ds_afr_ra.to_array().max(axis=0) 

ds_afr_rab['min'] =ds_afr_rab[labels].to_array().min(axis=0) 
ds_afr_ra['min'] =ds_afr_ra.to_array().min(axis=0) 


# uncertainity

ds_afr_rab['UNC'] = (ds_afr_rab['max'] - ds_afr_rab['min'])/2
ds_afr_ra['UNC'] = (ds_afr_ra['max'] - ds_afr_ra['min'])/2

'''
### coefficient of variation
def cv(x):
    mu = x.mean()
    residual = x - mu
    return (np.sqrt(np.power(residual,2))/mu)* 100



ds_afr_rab['RSD'] = xr.apply_ufunc(cv, ds_afr_rab[best_n_features])

ds_afr_ra['RSD'] = xr.apply_ufunc(cv, ds_afr_ra[best_n_features])


afr_rab_df = pd.read_csv(DIR/'Grids'/'Outputs'/f"{best_n_features}_rab.xyz", sep='\t')[['X','Y','Prediction']]


##  difff
'''
ds_afr_rab['Q_Diff_11_04'] = ds_afr_rab[best_n_features] - ds_afr_rab['RFE_04']
ds_afr_rab['Q_Diff_11_09'] = ds_afr_rab[best_n_features] - ds_afr_rab['RFE_09']
ds_afr_rab['Q_Diff_11_16'] = ds_afr_rab[best_n_features] - ds_afr_rab['RFE_16']

ds_afr_ra['Q_Diff_11_04'] = ds_afr_rab[best_n_features] - ds_afr_ra['RFE_04']
ds_afr_ra['Q_Diff_11_09'] = ds_afr_rab[best_n_features] - ds_afr_ra['RFE_09']
ds_afr_ra['Q_Diff_11_16'] = ds_afr_rab[best_n_features] - ds_afr_ra['RFE_16']
'''

# ra


Afr_ra_lat = Afr_OD_ra['lat'].values
Afr_ra_lon =  Afr_OD_ra['lon'].values
y_test_ra = Afr_OD_ra[target].values
y_pred_ra = ds_afr_ra[f'{best_n_features}'].values.ravel()[Afr_OD_ra['grid_index_afr']]
resid_ra = y_test_ra - y_pred_ra

#rab

Afr_rab_lat = Afr_OD_rab['lat'].values
Afr_rab_lon =  Afr_OD_rab['lon'].values
y_test_rab = Afr_OD_rab[target].values
y_pred_rab = ds_afr_rab[f'{best_n_features}'].values.ravel()[Afr_OD_rab['grid_index_afr']]
resid_rab = y_test_rab - y_pred_rab


### rab for NOD



Afr_rab_NOD_lat = Afr_NOD_rab['lat'].values
Afr_rab_NOD_lon =  Afr_NOD_rab['lon'].values
y_test_NOD_rab = Afr_NOD_rab[target].values
y_pred_NOD_rab = ds_afr_rab[f'{best_n_features}'].values.ravel()[Afr_NOD_rab['grid_index_afr']]
resid_NOD_rab = y_test_NOD_rab - y_pred_NOD_rab



##


print(f' len of ra  : {len(y_test_ra)}')
print(f' len of rab : {len(y_test_rab)}')

print(f" > 125 : {len(Afr_OD_rab[Afr_OD_rab[target] > 125])/len(Afr_OD_rab) * 100}")
print(f" < 50  : {len(Afr_OD_rab[Afr_OD_rab[target] < 50])/len(Afr_OD_rab) * 100}")

print(len(Afr_OD_rab))

#len(Afr_rab[target])
# Out:
#  len of ra  : 1545
#  len of rab : 1720
#  > 125 : 5.523255813953488
#  < 50  : 27.790697674418606
# 1720

# %%
afr_rab_df
# Out:
#                X     Y  Prediction
# 0     -20.000000 -37.0   60.053063
# 1     -19.492958 -37.0   59.263662
# 2     -18.985915 -37.0   59.011464
# 3     -18.478873 -37.0   59.103431
# 4     -17.971831 -37.0   58.732555
# ...          ...   ...         ...
# 22555  49.971831  38.0   61.576694
# 22556  50.478873  38.0   58.583624
# 22557  50.985915  38.0   56.822963
# 22558  51.492958  38.0   56.149165
# 22559  52.000000  38.0   55.060255
#
# [22560 rows x 3 columns]

# %%
sub_figs = list('ABCDEFGHIJKLMNOPQRSTUVWXYZ')

#create two datsets for A ratibng and b ratings
hq_f = DIR / 'Dataset'/ 'References'/'q_Heat_Flow'/'NGHF.csv'



elev_cut = -1000




record_total = pd.read_csv(hq_f)

record_total = record_total.rename(columns={'heat-flow (mW/m2)': target, 'longitude': 'lon', 'latitude': 'lat'})


print(len(record_total))


hq_clean = record_total.dropna(subset = ['lon', 'lat', target])
hq_clean = hq_clean[hq_clean[target].between(hq_lower_bound, hq_upper_bound, inclusive='both')]

hq_no_pole = hq_clean[hq_clean['lat'].between(world_lat_min, world_lat_max, inclusive='both')]
hq_deep = hq_no_pole[(hq_no_pole['elevation (m)']>elev_cut)][['lon', 'lat',target]]



hq_final_a = hq_no_pole[(hq_no_pole ['code6']=='A') & (hq_no_pole ['elevation (m)']>elev_cut)][['lon', 'lat',target]]
hq_final_b = hq_no_pole[(hq_no_pole ['code6']=='B') & (hq_no_pole ['elevation (m)']>elev_cut)][['lon', 'lat',target]]

hq_final_c = hq_no_pole[(hq_no_pole ['code6']=='C') & (hq_no_pole ['elevation (m)']>elev_cut)][['lon', 'lat',target]]
hq_final_d = hq_no_pole[(hq_no_pole ['code6']=='D') & (hq_no_pole ['elevation (m)']>elev_cut)][['lon', 'lat',target]]


######A rating

hq_final_a.columns = ['lon', 'lat', target]


hq_final_a = hq_final_a.round(3)

print(len(hq_final_a))
hq_final_a.replace(' ', np.nan, inplace=True)
hq_final_a.sort_values(by=['lon', 'lat'], ascending=True, inplace=True)
hq_final_a.reset_index( inplace=True,drop=True)

assert hq_final_a['lon'].max() <= 180, f" max lon {hq_final_a['lon'].max()}"
assert hq_final_a['lon'].min() >= -180, f" min lon {hq_final_a['lon'].min()}"
assert hq_final_a['lat'].max() <= 90, f" max lat {hq_final_a['lat'].max()}"
assert hq_final_a['lat'].min() >= -90, f" min lat {hq_final_a['lon'].min()}"


###### B rating

hq_final_b.columns = ['lon', 'lat', target]


hq_final_b = hq_final_b.round(3)

hq_final_b.replace(' ', np.nan, inplace=True)
hq_final_b.sort_values(by=['lon', 'lat'], ascending=True, inplace=True)
hq_final_b.reset_index( inplace=True,drop=True)


assert hq_final_b['lon'].max() <= 180, f" max lon {hq_final_b['lon'].max()}"
assert hq_final_b['lon'].min() >= -180, f" min lon {hq_final_b['lon'].min()}"
assert hq_final_b['lat'].max() <= 90, f" max lat {hq_final_b['lat'].max()}"
assert hq_final_b['lat'].min() >= -90, f" min lat {hq_final_b['lon'].min()}"



###### C rating

hq_final_c.columns = ['lon', 'lat', target]


hq_final_c = hq_final_c.round(3)

hq_final_c.replace(' ', np.nan, inplace=True)
hq_final_c.sort_values(by=['lon', 'lat'], ascending=True, inplace=True)
hq_final_c.reset_index( inplace=True,drop=True)
print(len(hq_final_c))

assert hq_final_c['lon'].max() <= 180, f" max lon {hq_final_c['lon'].max()}"
assert hq_final_c['lon'].min() >= -180, f" min lon {hq_final_c['lon'].min()}"
assert hq_final_c['lat'].max() <= 90, f" max lat {hq_final_c['lat'].max()}"
assert hq_final_c['lat'].min() >= -90, f" min lat {hq_final_c['lon'].min()}"


###### D rating 

hq_final_d.columns = ['lon', 'lat', target]


hq_final_d = hq_final_d.round(3)

hq_final_d.replace(' ', np.nan, inplace=True)
hq_final_d.sort_values(by=['lon', 'lat'], ascending=True, inplace=True)
hq_final_d.reset_index( inplace=True,drop=True)


assert hq_final_d['lon'].max() <= 180, f" max lon {hq_final_d['lon'].max()}"
assert hq_final_d['lon'].min() >= -180, f" min lon {hq_final_d['lon'].min()}"
assert hq_final_d['lat'].max() <= 90, f" max lat {hq_final_d['lat'].max()}"
assert hq_final_d['lat'].min() >= -90, f" min lat {hq_final_d['lon'].min()}"


print(len(hq_final_a))
print(len(hq_final_b))

print(len(hq_final_c))
print(len(hq_final_d))


print('terminated')

fig, ax = plt.subplots( figsize=(20, 12))
#print(plt.style.available)
#plt.style.use('_classic_test_patch')

sns.set(style='white', font_scale = 2.6)

record_total[target].hist(bins=100, range = (hq_lower_bound, hq_upper_bound), ax=ax,
                          label = f'All records (n={len(record_total):,})')
                          
hq_clean[target].hist(bins=100, range = (hq_lower_bound, hq_upper_bound), ax=ax,
                      label = f'Excluded incomplete records (n={len(hq_clean):,})')

hq_no_pole[target].hist(bins=100, range = (hq_lower_bound, hq_upper_bound), ax=ax,
                         label = f'Excluded high latitudes (n={len(hq_no_pole):,})')
hq_deep[target].hist(bins=100, range = (hq_lower_bound, hq_upper_bound), ax=ax,
                         label = f'Excluded deeper than {abs(elev_cut)} m (n={len(hq_deep):,})')

pd.concat([hq_final_a[target], hq_final_b[target], hq_final_c[target], 
           hq_final_d[target]]).hist(
    bins=100, range = (hq_lower_bound, hq_upper_bound), ax=ax,
label = f'Rating $A$-$D$ (n={len(hq_final_a) + len(hq_final_b)+ len(hq_final_c) + len(hq_final_d):,})')
pd.concat([hq_final_a[target], hq_final_b[target], hq_final_c[target]]).hist(
    bins=100,  range = (hq_lower_bound, hq_upper_bound),ax=ax,
label = f'Rating $A$-$C$ (n={len(hq_final_a) + len(hq_final_b) + len(hq_final_c):,})')
pd.concat([hq_final_a[target], hq_final_b[target]]).hist(
    bins=100,  range = (hq_lower_bound, hq_upper_bound),ax=ax,
                        label = f'Rating $A$-$B$ (n={len(hq_final_a) + len(hq_final_b ):,})')
hq_final_a[target].hist(bins=100,  range = (hq_lower_bound, hq_upper_bound),ax=ax,
                        label = f'Rating $A$ (n={len(hq_final_a):,})')


ax.set_title(f'{sub_figs[2]})', loc ='left', pad=20, )
ax.legend()
ax.set_ylabel(f'$n$')

ax.set_xlabel('GHF [mW/m2]')
ax.grid(False)

#ax.set_title('Distribution of different global Ghq values', pad=40,)


fig.savefig(DIR/'Fig'/"fig_s1b.jpeg", bbox_inches='tight', dpi=300 , pad_inches=0.2)
# Out:
# 69729
# 5718
# 20911
# 5718
# 6843
# 20911
# 1009
# terminated

# %%
hq_afr_lat = record_total[record_total['lat'].between(afr_lat_min, afr_lat_max, inclusive='both')]
record_total_afr = hq_afr_lat[hq_afr_lat['lon'].between(afr_lon_min, afr_lon_max, inclusive='both')]



hq_no_pole_afr = record_total_afr.dropna(subset = ['lon', 'lat', target])
hq_no_pole_afr = hq_no_pole_afr[hq_no_pole_afr[target].between(hq_lower_bound, hq_upper_bound, inclusive='both')]


hq_no_pole_afr = hq_no_pole_afr[hq_no_pole_afr[target].between(hq_lower_bound, hq_upper_bound, inclusive='both')]


#hq_no_pole_afr = hq_clean[hq_clean['lat'].between(world_lat_min, world_lat_max, inclusive='both')]
hq_deep_afr = hq_no_pole_afr[(hq_no_pole_afr['elevation (m)']>elev_cut)][['lon', 'lat',target]]



hq_final_a_afr = hq_no_pole_afr[(hq_no_pole_afr ['code6']=='A') & (hq_no_pole_afr ['elevation (m)']>elev_cut)][['lon', 'lat',target]]
hq_final_b_afr= hq_no_pole_afr[(hq_no_pole_afr ['code6']=='B') & (hq_no_pole_afr ['elevation (m)']>elev_cut)][['lon', 'lat',target]]

hq_final_c_afr = hq_no_pole_afr[(hq_no_pole_afr ['code6']=='C') & (hq_no_pole_afr ['elevation (m)']>elev_cut)][['lon', 'lat',target]]
hq_final_d_afr = hq_no_pole_afr[(hq_no_pole_afr ['code6']=='D') & (hq_no_pole_afr ['elevation (m)']>elev_cut)][['lon', 'lat',target]]
hq_final_z_afr = hq_no_pole_afr[(hq_no_pole_afr ['code6']=='Z') & (hq_no_pole_afr ['elevation (m)']>elev_cut)][['lon', 'lat',target]]





fig, ax = plt.subplots( figsize=(20, 12))
#print(plt.style.available)
#plt.style.use('_classic_test_patch')

sns.set(style='white', font_scale = 2.6)


record_total_afr[target].hist(bins=100, range = (hq_lower_bound, hq_upper_bound), ax=ax,
                          label = f'All records (n={len(record_total_afr):,})')
                          
#hq_clean[target].hist(bins=100, range = (hq_lower_bound, hq_upper_bound), ax=ax,
#                      label = f'Excluded incomplete records (n={len(hq_clean):,})')
hq_no_pole_afr[target].hist(bins=100, range = (hq_lower_bound, hq_upper_bound), ax=ax,
                         label = f'Excluded incomplete records (n={len(hq_no_pole_afr):,})')
hq_deep_afr[target].hist(bins=100, range = (hq_lower_bound, hq_upper_bound), ax=ax,
                         label = f'Excluded deeper than {abs(elev_cut)} m (n={len(hq_deep_afr):,})')

pd.concat([hq_final_a_afr[target], hq_final_b_afr[target], hq_final_c_afr[target], hq_final_d_afr[target]]).hist(
    bins=100, range = (hq_lower_bound, hq_upper_bound), ax=ax,
                        label = f'Rating $A$-$D$ (n={len(hq_final_a_afr) + len(hq_final_b_afr) + len(hq_final_c_afr) + len(hq_final_d_afr):,})')
pd.concat([hq_final_a_afr[target], hq_final_b_afr[target], hq_final_c_afr[target]]).hist(
    bins=100,  range = (hq_lower_bound, hq_upper_bound),ax=ax,
                        label = f'Rating $A$-$C$ (n={len(hq_final_a_afr) + len(hq_final_b_afr) + len(hq_final_c_afr):,})')
pd.concat([hq_final_a_afr[target], hq_final_b_afr[target]]).hist(
    bins=100,  range = (hq_lower_bound, hq_upper_bound),ax=ax,
                        label = f'Rating $A$-$B$ (n={len(hq_final_a_afr) + len(hq_final_b_afr ):,})')
hq_final_a_afr[target].hist(bins=100,  range = (hq_lower_bound, hq_upper_bound),ax=ax,
                        label = f'Rating $A$ (n={len(hq_final_a_afr):,})')




hq_extreme_hi = record_total_afr[record_total_afr[target] >=hq_upper_bound]
lon_hq_extreme_hi = hq_extreme_hi['lon']
lat_hq_extreme_hi = hq_extreme_hi['lat']

hq_extreme_lw = record_total_afr[record_total_afr[target] <=hq_lower_bound]
lon_hq_extreme_lw = hq_extreme_lw['lon']
lat_hq_extreme_lw = hq_extreme_lw['lat']

ax.set_title(f'{sub_figs[2]})', loc ='left', pad=20, )
ax.legend()
ax.set_ylabel(f'$n$')

ax.set_xlabel('GHF [mW/m2]')
    
ax.grid(False)
#ax.set_title('Distribution of different global Ghq values', pad=40,)


fig.savefig(DIR/'Fig'/"fig_1b.jpeg", bbox_inches='tight', dpi=300 , pad_inches=0.2)

# %%
# visual inspection of imported datasets


region_gmt= [afr_lon_min, afr_lon_max,afr_lat_min, afr_lat_max]

projetion = 'M5.4i'

tectonics_shp_main = [DIR/'GMT'/'tectonics_shapefiles'/f'{filename}' \
         for filename in os.listdir(DIR/'GMT'/'tectonics_shapefiles')
                   if filename in ['CC.gmt', 'WAC.gmt', 'SMC.gmt', 'KA.gmt', ]]
labels_main = [filename[:-4]  for filename in os.listdir(DIR/'GMT'/'tectonics_shapefiles')
              if filename in ['CC.gmt', 'WAC.gmt', 'SMC.gmt', 'KA.gmt']]

tectonics_shp_sub = [DIR/'GMT'/'tectonics_shapefiles'/f'{filename}' \
         for filename in os.listdir(DIR/'GMT'/'tectonics_shapefiles')
                   if filename not in ['CC.gmt', 'WAC.gmt', 'SMC.gmt', 'KA.gmt',]
                    and 'gmt' in filename]
labels_sub = [filename[:-4]  for filename in os.listdir(DIR/'GMT'/'tectonics_shapefiles') 
             if filename not in ['CC.gmt', 'WAC.gmt', 'SMC.gmt', 'KA.gmt',]
             and 'gmt' in filename]

volc_erup = pd.read_csv(DIR/'GMT'/'tectonics_shapefiles'/'volcanic_eruptions.dat', sep='\s')
# congo co KA kalhari
 


pygmt.config(
MAP_GRID_CROSS_SIZE_PRIMARY=0.10,
MAP_GRID_CROSS_SIZE_SECONDARY=0.10,
MAP_TICK_LENGTH_PRIMARY=0.05,
MAP_TICK_LENGTH_SECONDARY=0.15,
FONT_ANNOT_PRIMARY=12,
FONT_ANNOT_SECONDARY=10)

cmap_ghf = pygmt.makecpt(
        cmap=DIR/'GMT'/'temperature.cpt', #temp 19lev
    #cmap='lajolla',
        series='30/130',
        #truncate = '40/140',
        #continuous=True,
        reverse=False,
    )
# Out:
# Plotting.....

# %%
print('Plotting.....', end='\n\n')

fig = pygmt.Figure()




fig.basemap(frame=True, region=region_afr, projection=projection,)


fig.plot(x=0, y=0,  projection=projection, cmap=False,
      label='"GHF measurments"', 
              pen="0.5p", style="c0.21c")

#avoid interpolation



fig.grdimage(
            ds_afr_rab[best_n_features], 
            cmap=cmap_ghf,
             #bcln
             interpolation='b',  
             #dpi='i', 
            )

fig.coast(
    #water="lightblue", 
    shorelines="0.1p,black",
    borders=["1/0.001p,black"],
    lakes="lightblue",
    rivers="lightblue" ,
    #dcw="=AS,=EU+gdarkgrey",
    resolution = 'f',
    )


fig.plot(x=hq_final_a_afr.lon, y=hq_final_a_afr.lat,  cmap=True, projection=projection,
     color=hq_final_a_afr[target], transparency =50,
              pen="0.5p,black", style="c0.21c")
fig.plot(x=hq_final_b_afr.lon, y=hq_final_b_afr.lat,  cmap=True, projection=projection,
     color=hq_final_b_afr[target],transparency =50,
              pen="0.5p,black", style="c0.21c")


fig.colorbar(frame=["af", "x+lGHF\t[mW/m@+2@+]"],
                     position=f"g{str(afr_lon_max +4)}/{str(afr_lat_min+1)}+w15c/0.5c+v+e")


fig.legend(position="g-15/-15", box=False)



fig.show(width=800)

fig.savefig(DIR/'fig'/"fig_5.pdf", dpi=300 )
fig.savefig(DIR/'fig'/"fig_5.jpg", dpi=300 )
# Out:
# Plotting.....
# grdinfo [ERROR]: File C:\Users\Home\Magued\papers\antratica\model\AQ1_Africa\AQRFR_2\Grids\Outputs\ds_afr_rfr_rab.nc was not found
# grdinfo [ERROR]: Cannot find file C:\Users\Home\Magued\papers\antratica\model\AQ1_Africa\AQRFR_2\Grids\Outputs\ds_afr_rfr_rab.nc
# grdinfo [ERROR]: Must specify one or more input files
# ---------------------------------------------------------------------------
# GMTCLibError                              Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_13772\2163007957.py in <cell line: 19>()
#      17
#      18
# ---> 19 fig.grdimage(
#      20             ds_afr_rab[best_n_features],
#      21             cmap=cmap_ghf,
#
# ~\.conda\envs\AFQ2\lib\site-packages\pygmt\helpers\decorators.py in new_module(*args, **kwargs)
#     583                     )
#     584                     warnings.warn(msg, category=SyntaxWarning, stacklevel=2)
# --> 585             return module_func(*args, **kwargs)
#     586
#     587         new_module.aliases = aliases
#
# ~\.conda\envs\AFQ2\lib\site-packages\pygmt\helpers\decorators.py in new_module(*args, **kwargs)
#     723                         kwargs[arg] = separators[fmt].join(f"{item}" for item in value)
#     724             # Execute the original function and return its output
# --> 725             return module_func(*args, **kwargs)
#     726
#     727         return new_module
#
# ~\.conda\envs\AFQ2\lib\site-packages\pygmt\src\grdimage.py in grdimage(self, grid, **kwargs)
#     171                 kwargs["I"] = stack.enter_context(shading_context)
#     172
# --> 173             fname = stack.enter_context(file_context)
#     174             lib.call_module(
#     175                 module="grdimage", args=build_arg_string(kwargs, infile=fname)
#
# ~\.conda\envs\AFQ2\lib\contextlib.py in enter_context(self, cm)
#     446         _cm_type = type(cm)
#     447         _exit = _cm_type.__exit__
# --> 448         result = _cm_type.__enter__(cm)
#     449         self._push_cm_exit(cm, _exit)
#     450         return result
#
# ~\.conda\envs\AFQ2\lib\contextlib.py in __enter__(self)
#     117         del self.args, self.kwds, self.func
#     118         try:
# --> 119             return next(self.gen)
#     120         except StopIteration:
#     121             raise RuntimeError("generator didn't yield") from None
#
# ~\.conda\envs\AFQ2\lib\site-packages\pygmt\clib\session.py in virtualfile_from_grid(self, grid)
#    1324         >>> # The output is: w e s n z0 z1 dx dy n_columns n_rows reg gtype
#    1325         """
# -> 1326         _gtype = {0: "GMT_GRID_IS_CARTESIAN", 1: "GMT_GRID_IS_GEO"}[grid.gmt.gtype]
#    1327         _reg = {0: "GMT_GRID_NODE_REG", 1: "GMT_GRID_PIXEL_REG"}[grid.gmt.registration]
#    1328
#
# ~\.conda\envs\AFQ2\lib\site-packages\xarray\core\extensions.py in __get__(self, obj, cls)
#      36
#      37         try:
# ---> 38             accessor_obj = self._accessor(obj)
#      39         except AttributeError:
#      40             # __getattr__ on data object will swallow any AttributeErrors
#
# ~\.conda\envs\AFQ2\lib\site-packages\pygmt\accessors.py in __init__(self, xarray_obj)
#      33             # the shortened summary information of `grdinfo`.
#      34             self._registration, self._gtype = map(
# ---> 35                 int, grdinfo(self._source, per_column="n").split()[-2:]
#      36             )
#      37         except (KeyError, ValueError):
#
# ~\.conda\envs\AFQ2\lib\site-packages\pygmt\helpers\decorators.py in new_module(*args, **kwargs)
#     583                     )
#     584                     warnings.warn(msg, category=SyntaxWarning, stacklevel=2)
# --> 585             return module_func(*args, **kwargs)
#     586
#     587         new_module.aliases = aliases
#
# ~\.conda\envs\AFQ2\lib\site-packages\pygmt\helpers\decorators.py in new_module(*args, **kwargs)
#     723                         kwargs[arg] = separators[fmt].join(f"{item}" for item in value)
#     724             # Execute the original function and return its output
# --> 725             return module_func(*args, **kwargs)
#     726
#     727         return new_module
#
# ~\.conda\envs\AFQ2\lib\site-packages\pygmt\src\grdinfo.py in grdinfo(grid, **kwargs)
#     115             file_context = lib.virtualfile_from_data(check_kind="raster", data=grid)
#     116             with file_context as infile:
# --> 117                 lib.call_module(
#     118                     module="grdinfo",
#     119                     args=build_arg_string(kwargs, infile=infile, outfile=outfile.name),
#
# ~\.conda\envs\AFQ2\lib\site-packages\pygmt\clib\session.py in call_module(self, module, args)
#     504         )
#     505         if status != 0:
# --> 506             raise GMTCLibError(
#     507                 f"Module '{module}' failed with status code {status}:\n{self._error_message}"
#     508             )
#
# GMTCLibError: Module 'grdinfo' failed with status code 72:
# grdinfo [ERROR]: File C:\Users\Home\Magued\papers\antratica\model\AQ1_Africa\AQRFR_2\Grids\Outputs\ds_afr_rfr_rab.nc was not found
# grdinfo [ERROR]: Cannot find file C:\Users\Home\Magued\papers\antratica\model\AQ1_Africa\AQRFR_2\Grids\Outputs\ds_afr_rfr_rab.nc
# grdinfo [ERROR]: Must specify one or more input files

# %%
# visual inspection of imported datasets




print('Plotting.....', end='\n\n')




fig = pygmt.Figure()



fig.basemap(frame=True, region=region_afr, projection=projection,)


fig.plot(x=0, y=0,  projection=projection, cmap=False,
      label='"GHF measurments"', 
              pen="0.5p", style="c0.21c")

#avoid interpolation

data_bmean = pygmt.blockmedian(
    data=afr_rab_df, region=region_afr, spacing="0.5"
)

grid = pygmt.surface(data=data_bmean )

fig.grdimage(
            #ds_afr_rab[best_n_features], 
            grid,
    cmap=cmap_ghf,
             #bcln
             interpolation='b',  
             #dpi='i', 
            )

fig.coast(
    water="lightblue", 
    shorelines="0.1p,black",
    borders=["1/0.001p,black"],
    lakes="lightblue",
    rivers="lightblue" ,
    dcw="=AS,=EU+gdarkgrey",
    resolution = 'i',
    )


fig.plot(x=hq_final_a_afr.lon, y=hq_final_a_afr.lat,  cmap=True, projection=projection,
     color=hq_final_a_afr[target], transparency =50,
              pen="0.5p,black", style="c0.21c")
fig.plot(x=hq_final_b_afr.lon, y=hq_final_b_afr.lat,  cmap=True, projection=projection,
     color=hq_final_b_afr[target],transparency =50,
              pen="0.5p,black", style="c0.21c")


fig.colorbar(frame=["af", "x+lGHF\t[mW/m@+2@+]"],
                     position=f"g{str(afr_lon_max +4)}/{str(afr_lat_min+1)}+w15c/0.5c+v+e")


fig.legend(position="g-15/-15", box=False)



fig.show(width=800)

fig.savefig(DIR/'fig'/"fig_5.pdf", dpi=300 )
fig.savefig(DIR/'fig'/"fig_5.jpg", dpi=300 )

# %%
# visual inspection of imported datasets



print('Plotting.....', end='\n\n')


fig = pygmt.Figure()




fig.basemap(frame=True, region=region_afr, projection=projection,)




#avoid interpolation

fig.grdimage(ds_afr_rab[best_n_features], 
             cmap=cmap_ghf,
             #interpolation  = 'n',  dpi='i', 
            )

fig.coast(
    water="lightblue", 
    shorelines="0.1p,black",
    borders=["1/0.001p,black"],
    lakes="lightblue",
    rivers="lightblue" ,
    #dcw="=AS,=EU+gdarkgrey",
    #resolution = 'i',
    )




fig.colorbar(frame=["af", "x+lGHF\t[mW/m@+2@+]"],
                     position=f"g{str(afr_lon_max +4)}/{str(afr_lat_min+1)}+w15c/0.5c+v+e")



fig.show(width=800)

# %%
fig = pygmt.Figure()


fig.basemap(frame=True, region=region_gmt, projection=projection,)



#for legend

fig.plot(x=0, y=0,  projection=projection,
      label=f'"A Ratings"',
              pen="0.5p", style="c0.2c")
fig.plot(x=0, y=0,  projection=projection,
      label=f'"B Ratings"',
              pen="0.5p", style="t0.22c")        
fig.plot(x=0, y=0,  projection=projection,
      label=f'"C Ratings"',
              pen="0.5p,red", style="s0.22c")   
fig.plot(x=0, y=0,  projection=projection,
      label=f'"D Ratings"',
              pen="0.5p,red", style="d0.22c")        
fig.plot(x=0, y=0,  projection=projection,
     label=f'"Z Ratings"',
              pen="0.5p,red", style="h0.22c") 


fig.coast(

    projection=projection,
    #shorelines=0.5,
    water="lightblue", 
    shorelines="0.01p,black",
    borders=["1/0.01p,black"],
    lakes="lightblue",
    rivers="lightblue" ,
    land='darkgrey',
    dcw="=AS,=EU+gdarkgrey",
    resolution = 'i',

    #water='white',
    )


#plot tectonics
for shape, label in zip(tectonics_shp_main, labels_main):
    shape_xy = pd.read_csv(shape, header=None, sep='\s')
    fig.plot(x=shape_xy.iloc[:,0], y=shape_xy.iloc[:,1], projection=projection, 
             region=region_gmt,   pen='1.5,white')      

    labels = [ 'WAC', 'SMC','CC', 'KA']
starts_labels = [[-10,18],  [20,18], [20,0], [20,-23]]  
for label ,starts_label in zip(labels, starts_labels):
    fig.text(
            text=label, x=starts_label[0], y=starts_label[1],  
            font="13p,Helvetica-Bold,white" ,  justify="ML"
        )
    
# plot info
fig.plot(x=volc_erup.Lon, y=volc_erup.Lat,  projection=projection,
     color='white', label=f'"Volcanoes"',
              pen="0.5p", style="a0.25c")
fig.plot(x=hq_final_a_afr.lon, y=hq_final_a_afr.lat,  cmap=cmap_ghf, projection=projection,
     color=hq_final_a_afr[target], #label=f"'A Rating'",
              pen="0.1p,black", style="c0.19c")

fig.plot(x=hq_final_b_afr.lon, y=hq_final_b_afr.lat,  cmap=cmap_ghf, projection=projection,
     color=hq_final_b_afr[target], #label="'B Rating'",
              pen="0.1p,black", style="t0.21c")
fig.plot(x=hq_final_c_afr.lon, y=hq_final_c_afr.lat,  cmap=cmap_ghf, projection=projection,
     color=hq_final_c_afr[target], #label="'C Rating'",
              pen="0.1p,black", style="s0.21c" , transparency = 60)
fig.plot(x=hq_final_d_afr.lon, y=hq_final_d_afr.lat,   cmap=cmap_ghf, projection=projection,
     color=hq_final_d_afr[target], #label="'B Rating'",
              pen="0.1p,black", style="d0.21c" , transparency = 60)
fig.plot(x=hq_final_z_afr.lon, y=hq_final_z_afr.lat,   cmap=cmap_ghf, projection=projection,
     color=hq_final_z_afr[target], #label="'C Rating'",
              pen="0.1p,black", style="h0.21c" , transparency = 60)



fig.colorbar(frame=["af","x+lGHF\t[mW/m@+2@+]"],
        position=f"g{str(afr_lon_max +4)}/{str(afr_lat_min+1)}+w15c/0.5c+v+e")


fig.text(text="_", x=-14.3, y=-22.5, font="25p,Helvetica,white")
fig.text(text="Cratons", x=-8.7, y=-23, font="10p,Helvetica,black")

fig.legend(position="g-15/-23", box=False)
fig.show(width=800)

fig.savefig(DIR/'fig'/"fig_4.pdf", dpi=300 )
fig.savefig(DIR/'fig'/"fig_4.jpg", dpi=900 )

# %%
fig = pygmt.Figure()



fig.basemap(frame=True, region=region_gmt, projection=projection,)



#for legend

fig.plot(x=0, y=0,  projection=projection,
      label=f'"A Ratings"',
              pen="0.5p", style="c0.2c")
fig.plot(x=0, y=0,  projection=projection,
      label=f'"B Ratings"',
              pen="0.5p", style="t0.22c")        
fig.plot(x=0, y=0,  projection=projection,
      label=f'"C Ratings"',
              pen="0.5p", style="s0.22c")   
fig.plot(x=0, y=0,  projection=projection,
      label=f'"D Ratings"',
              pen="0.5p", style="d0.22c")        
fig.plot(x=0, y=0,  projection=projection,
      label=f'"Z Ratings"',
              pen="0.5p", style="h0.22c") 


fig.coast(
    projection=projection,
    #shorelines=0.5,
    water="lightblue", 
    shorelines="0.01p,black",
    borders=["1/0.01p,black"],
    lakes="lightblue",
    rivers="lightblue" ,
    land='darkgrey',
    dcw="=AS,=EU+gdarkgrey",
    resolution = 'i',

    #water='white',
    )


# plot info
fig.plot(x=volc_erup.Lon, y=volc_erup.Lat,  projection=projection,
     color='white', label=f'"Volcanoes"',
              pen="0.5p", style="a0.25c")
fig.plot(x=hq_final_a_afr.lon, y=hq_final_a_afr.lat,  cmap=cmap_ghf, projection=projection,
     color=hq_final_a_afr[target], #label=f"'A Rating'",
              pen="0.1p,black", style="c0.19c")

fig.plot(x=hq_final_b_afr.lon, y=hq_final_b_afr.lat, cmap=cmap_ghf, projection=projection,
     color=hq_final_b_afr[target], #label="'B Rating'",
              pen="0.1p,black", style="t0.21c")
fig.plot(x=hq_final_c_afr.lon, y=hq_final_c_afr.lat,  cmap=cmap_ghf, projection=projection,
     color=hq_final_c_afr[target], #label="'C Rating'",
              pen="0.1p,black", style="s0.21c")
fig.plot(x=hq_final_d_afr.lon, y=hq_final_d_afr.lat,   cmap=cmap_ghf, projection=projection,
     color=hq_final_d_afr[target], #label="'B Rating'",
              pen="0.1p,black", style="d0.21c")
fig.plot(x=hq_final_z_afr.lon, y=hq_final_z_afr.lat, cmap=cmap_ghf, projection=projection,
     color=hq_final_z_afr[target], #label="'C Rating'",
              pen="0.1p,black", style="h0.21c")



#plot tectonics
for shape, label in zip(tectonics_shp_main, labels_main):
    shape_xy = pd.read_csv(shape, header=None, sep='\s')
    fig.plot(x=shape_xy.iloc[:,0], y=shape_xy.iloc[:,1], projection=projection, 
             region=region_gmt,   pen='1.5,white')      



for shape, label in zip(tectonics_shp_sub, labels_sub):
    shape_xy = pd.read_csv(shape, header=None, sep='\s')
    fig.plot(x=shape_xy.iloc[:,0], y=shape_xy.iloc[:,1], projection=projection, 
             region=region_gmt,   pen='1,white,..-')      
                  #pen="1p,red,--", style="c0.01i")
    #fig.text(x=shape_xy.iloc[:,0].min()+4, y=shape_xy.iloc[:,1].median()-2, font='15' ,text=label, justify="ML")

fig.colorbar(frame=["af","x+lGHF\t[mW/m@+2@+]"], 
        position=f"g{str(afr_lon_max +4)}/{str(afr_lat_min+1)}+w15c/0.5c+v+e")

labels = [ 'KA', 'NNB', 'KC', 'BB', 'TC', 'ASZ', 'ZC', 'RB']
starts = [[8,-18], [8,-31],[35,-32],[47,-10],[47,-5],[46,0], [40,-20],[8,-25]]   

starts_labels = [ [4,-18], [2,-31],[36,-32], [48,-10],[47,-5],[46,0], [40,-20],[4,-25],]   

ends = [[16,-23.5], [21,-31],[30,-27], [30,-11], [33,-5], [33,4], [30,-19],[19,-26]]

for start, end, label ,starts_label in zip(starts, ends, labels, starts_labels):
    style = "=0.3c+s+e+a30+gred+h0.3+p0.3p,red"
    data = np.array([start + end])
    fig.plot(data=data, style=style, pen="1.0p,red")

    fig.text(
        text=label, x=starts_label[0], y=starts_label[1], 
        font="13p,Helvetica-Bold,white" ,  justify="ML"
    )

labels = [ 'WAC', 'SMC','CC', 'AAO', 'KB', 
          'AC', 'CG']
starts_labels = [[-10,18],  [20,18], [20,0],[-6,29],[22,-9], 
                 [13.3,-14], [10, 1],]  
for label ,starts_label in zip(labels, starts_labels):
    fig.text(
            text=label, x=starts_label[0], y=starts_label[1],  
            font="13p,Helvetica-Bold,white" ,  justify="ML"
        )
#legend

fig.text(text="_", x=-14.3, y=-22.5, font="25p,Helvetica,white")
fig.text(text="Cratons", x=-8.7, y=-23, font="10p,Helvetica,black")
fig.text(text="...", x=-14.3, y=-25, font="25p,Helvetica,white")
fig.text(text="Cratonic Blocks", x=-5.4, y=-24.9, font="10p,Helvetica,black")


fig.legend(position="g-15/-23", box=False)

fig.show(width=800)


fig.savefig(DIR/'fig'/"fig_4.pdf", dpi=300 )
fig.savefig(DIR/'fig'/"fig_4.jpg", dpi=300 )

# %%
fig = pygmt.Figure()



fig.basemap(frame=True, region=region_afr, projection=projection,)



#for legend

fig.plot(x=0, y=0,  projection=projection,
      label=f'"A Ratings"',
              pen="0.5p", style="c0.2c")
fig.plot(x=0, y=0,  projection=projection,
     label=f'"B Ratings"',
              pen="0.5p", style="t0.22c")        
fig.plot(x=0, y=0,  projection=projection,
      label=f'"C Ratings"',
              pen="0.5p", style="s0.22c")   
fig.plot(x=0, y=0,  projection=projection,
      label=f'"D Ratings"',
              pen="0.5p", style="d0.22c")        
fig.plot(x=0, y=0,  projection=projection,
      label=f'"Z Ratings"',
              pen="0.5p", style="h0.22c") 



# GHF plotting
fig.grdimage(ds_afr_rab[best_n_features], 
             cmap=cmap_ghf,
             #interpolation  = 'n',  dpi='i', 
            )

fig.coast(
    projection=projection,
    water="lightblue", 
    shorelines="0.01p,black",
    borders=["1/0.01p,black"],
    lakes="lightblue",
    rivers="lightblue" ,
    #land='darkgrey',
   # dcw="=AS,=EU+gdarkgrey",
    #resolution = 'i',

    #water='white',
    )

# plot info
fig.plot(x=volc_erup.Lon, y=volc_erup.Lat,  projection=projection,
      label=f'"Volcanoes"', transparency =50,
              pen="0.01p", style="a0.25c")
fig.plot(x=hq_final_a_afr.lon, y=hq_final_a_afr.lat,  cmap=cmap_ghf, projection=projection,
     color=hq_final_a_afr[target], #label=f"'A Rating'",
              pen="0.1p,black", style="c0.19c")

fig.plot(x=hq_final_b_afr.lon, y=hq_final_b_afr.lat,  cmap=cmap_ghf, projection=projection,
     color=hq_final_b_afr[target], #label="'B Rating'",
              pen="0.1p,black", style="t0.21c")
fig.plot(x=hq_final_c_afr.lon, y=hq_final_c_afr.lat,   cmap=cmap_ghf, projection=projection,
     color=hq_final_c_afr[target], #label="'C Rating'",
              pen="0.1p,black", style="s0.21c")
fig.plot(x=hq_final_d_afr.lon, y=hq_final_d_afr.lat,  cmap=cmap_ghf,projection=projection,
     color=hq_final_d_afr[target], #label="'B Rating'",
              pen="0.1p,black", style="d0.21c")
fig.plot(x=hq_final_z_afr.lon, y=hq_final_z_afr.lat,   cmap=cmap_ghf, projection=projection,
     color=hq_final_z_afr[target], #label="'C Rating'",
              pen="0.1p,black", style="h0.21c")



#plot tectonics
for shape, label in zip(tectonics_shp_main, labels_main):
    shape_xy = pd.read_csv(shape, header=None, sep='\s')
    fig.plot(x=shape_xy.iloc[:,0], y=shape_xy.iloc[:,1], projection=projection, 
             region=region_gmt,   pen='1.5,white')      



for shape, label in zip(tectonics_shp_sub, labels_sub):
    shape_xy = pd.read_csv(shape, header=None, sep='\s')
    fig.plot(x=shape_xy.iloc[:,0], y=shape_xy.iloc[:,1], projection=projection, 
             region=region_gmt,   pen='1,white,..-')      
                  #pen="1p,red,--", style="c0.01i")
    #fig.text(x=shape_xy.iloc[:,0].min()+4, y=shape_xy.iloc[:,1].median()-2, font='15' ,text=label, justify="ML")

fig.colorbar(frame=["af","x+lGHF\t[mW/m@+2@+]"], 
        position=f"g{str(afr_lon_max +4)}/{str(afr_lat_min+1)}+w15c/0.5c+v+e")

labels = [ 'KA', 'NNB', 'KC', 'BB', 'TC', 'ASZ', 'ZC', 'RB']
starts = [[8,-18], [8,-31],[35,-32],[47,-10],[47,-5],[46,0], [40,-20],[10,-25]]   

starts_labels = [ [4,-18], [2,-31],[36,-32], [48,-10],[47,-5],[46,0], [40,-20],[6,-25],]   

ends = [[16,-23.5], [21,-31],[30,-27], [30,-11], [33,-5], [33,4], [30,-19],[19,-26]]

for start, end, label ,starts_label in zip(starts, ends, labels, starts_labels):
    style = "=0.3c+s+e+a30+gred+h0.3+p0.3p,red"
    data = np.array([start + end])
    fig.plot(data=data, style=style, pen="1.0p,red")

    fig.text(
        text=label, x=starts_label[0], y=starts_label[1], 
        font="13p,Helvetica-Bold,white" ,  justify="ML"
    )

labels = [ 'WAC', 'SMC','CC', 'AAO', 'KB', 
          'AC', 'CG']
starts_labels = [[-10,18],  [20,18], [20,0],[-6,29],[22,-9], 
                 [13.3,-14], [10, 1],]  
for label ,starts_label in zip(labels, starts_labels):
    fig.text(
            text=label, x=starts_label[0], y=starts_label[1],  
            font="13p,Helvetica-Bold,white" ,  justify="ML"
        )
    
#legend
fig.text(text="_", x=-14.3, y=-22.5, font="25p,Helvetica,white")
fig.text(text="Cratons", x=-7.8, y=-23, font="Helvetica,black")
fig.text(text="...", x=-14.3, y=-25, font="25p,Helvetica,white")
fig.text(text="Cratonic Blocks", x=-4.1, y=-25, font="Helvetica,black")


fig.legend(position="g-15/-23", box=False)
fig.show(width=800)

fig.savefig(DIR/'fig'/"fig_s7.pdf", dpi=300 )
fig.savefig(DIR/'fig'/"fig_s7.jpg", dpi=300 )

# %%
print('Plotting.....', end='\n\n')


fig = pygmt.Figure()


fig.basemap(frame=True, region=region_afr, projection=projection,)
#avoid interpolation

fig.grdimage(ds_afr_rab[best_n_features], 
             cmap=cmap_ghf,
             #interpolation  = 'n',  dpi='i', 
            )

fig.plot(x=0, y=0,  projection=projection, cmap=False,
      label='"GHF measurments"',
              pen="0.5p", style="c0.21c")

fig.coast(
    water="lightblue", 
    shorelines="0.1p,black",
    borders=["1/0.001p,black"],
    lakes="lightblue",
    rivers="lightblue" ,
    #dcw="=AS,=EU+gdarkgrey",
    #resolution = 'i',
    )



#plot tectonics
for shape, label in zip(tectonics_shp_main, labels_main):
    shape_xy = pd.read_csv(shape, header=None, sep='\s')
    fig.plot(x=shape_xy.iloc[:,0], y=shape_xy.iloc[:,1], projection=projection, 
             region=region_gmt,   pen='1.5,white')      

    labels = [ 'WAC', 'SMC','CC', 'KA']
starts_labels = [[-10,18],  [20,20], [20,-10], [20,-23]]  
for label ,starts_label in zip(labels, starts_labels):
    fig.text(
            text=label, x=starts_label[0], y=starts_label[1],  
            font="13p,Helvetica-Bold,white" ,  justify="ML"
        )
    

fig.plot(x=volc_erup.Lon, y=volc_erup.Lat,  projection=projection,
label=f'"Volcanoes"', transparency =50,
          pen="0.01p,black", style="a0.29c")
fig.plot(x=hq_final_a_afr.lon, y=hq_final_a_afr.lat,  cmap=cmap_ghf, projection=projection,
     color=hq_final_a_afr[target], transparency =50,
              pen="0.5p,black", style="c0.18c")
fig.plot(x=hq_final_b_afr.lon, y=hq_final_b_afr.lat,  cmap=cmap_ghf, projection=projection,
     color=hq_final_b_afr[target],transparency =50,
              pen="0.5p,black", style="c0.18c")


fig.colorbar(frame=["af","x+lGHF\t[mW/m@+2@+]"], 
        position=f"g{str(afr_lon_max +4)}/{str(afr_lat_min+1)}+w15c/0.5c+v+e")



'''
for shape, label in zip(tectonics_shp_sub, labels_sub):
    shape_xy = pd.read_csv(shape, header=None, sep='\s')
    fig.plot(x=shape_xy.iloc[:,0], y=shape_xy.iloc[:,1], projection=projection, 
             region=region_gmt,   pen='1,white,..-')      
                  #pen="1p,red,--", style="c0.01i")
    #fig.text(x=shape_xy.iloc[:,0].min()+4, y=shape_xy.iloc[:,1].median()-2, font='15' ,text=label, justify="ML")


labels = [ 'KA', 'NNB', 'KC', 'BB', 'TC', 'ASZ', 'ZC', 'RB']
starts = [[8,-18], [8,-31],[35,-32],[47,-10],[47,-5],[46,0], [40,-20],[8,-25]]   

starts_labels = [ [4,-18], [2,-31],[36,-32], [48,-10],[47,-5],[46,0], [40,-20],[4,-25],]   

ends = [[16,-23.5], [21,-31],[30,-27], [30,-11], [33,-5], [33,4], [30,-19],[19,-26]]

for start, end, label ,starts_label in zip(starts, ends, labels, starts_labels):
    style = "=0.3c+s+e+a30+gred+h0.3+p0.3p,red"
    data = np.array([start + end])
    fig.plot(data=data, style=style, pen="1.0p,red")

    fig.text(
        text=label, x=starts_label[0], y=starts_label[1], 
        font="13p,Helvetica-Bold,white" ,  justify="ML"
    )

labels = [ 'WAC', 'SMC','CC', 'AAO', 'KB', 
          'AC', 'CG']
starts_labels = [[-10,18],  [20,18], [20,0],[-6,29],[22,-9], 
                 [13.3,-14], [10, 1],]  
for label ,starts_label in zip(labels, starts_labels):
    fig.text(
            text=label, x=starts_label[0], y=starts_label[1],  
            font="13p,Helvetica-Bold,white" ,  justify="ML"
        )
    
#legend
fig.text(text="_", x=-14.3, y=-14.5, font="25p,Helvetica,white")
fig.text(text="Cratons", x=-8.7, y=-15, font="10p,Helvetica,black")
fig.text(text="...", x=-14.3, y=-17, font="25p,Helvetica,white")
fig.text(text="Cratonic Blocks", x=-5.4, y=-16.9, font="10p,Helvetica,black")'''



    
#legend
fig.text(text="_", x=-14.5, y=-14.9, font="25p,Helvetica,white")
fig.text(text="Cratons", x=-7.8, y=-15.2, font="Helvetica,black")
#fig.text(text="...", x=-14.3, y=-17, font="25p,Helvetica,white")
#fig.text(text="Cratonic Blocks", x=-5.4, y=-16.9, font="10p,Helvetica,black")

fig.legend(position="g-15/-15", box=False)

fig.show(width=800)



fig.savefig(DIR/'fig'/"fig_5_b.pdf", dpi=300 )
fig.savefig(DIR/'fig'/"fig_5_b.eps", dpi=300 )

# %%
fig = pygmt.Figure()




fig.basemap(frame=True, region=region_afr, projection=projection,)



#for legend

fig.plot(x=0, y=0,  projection=projection, cmap=False,
      label='"Residual GHF"',
              pen="0.5p", style="c0.21c")


fig.plot(x=0, y=0,  projection=projection,
     color='violet', label=f'"GHF > {hq_upper_bound}\t[mW/m@+2@+]"',
              pen="0.5p", style="t0.24c")
fig.plot(x=0, y=0,  projection=projection,
     color='red', label=f'"GHF < {hq_lower_bound}\t\t\t[mW/m@+2@+]"',
              pen="0.5p", style="t0.24c")


# GHF plotting
fig.grdimage(ds_afr_rab[best_n_features], 
             cmap=cmap_ghf,
             interpolation  = 'b',  
             #dpi='i', 
             #shading=shading,
            )

fig.coast(
    projection=projection,
    #water="lightblue", 
    shorelines="0.1p,black",
    borders=["1/0.01p,black"],
    lakes="lightblue",
    rivers="lightblue" ,
    #land='darkgrey',
   # dcw="=AS,=EU+gdarkgrey",
    #resolution = 'l',

    #water='white',
    )


 
fig.plot(x=hq_no_pole_afr.lon.values, y=hq_no_pole_afr.lat.values,  
             cmap=True, projection=projection, transparency =30,
         color=hq_no_pole_afr[target].values, #label="'C Rating'",
                  pen="0.5p,black", style="c0.16c")

fig.plot(x=lon_hq_extreme_hi , y=lat_hq_extreme_hi ,    projection=projection,                               
     color=  'violet' ,         pen="1p,black", style="t0.24c")

fig.plot(x=lon_hq_extreme_lw , y=lat_hq_extreme_lw ,    projection=projection,                               
     color=  'red' ,         pen="1p,black", style="t0.24c")


    #frame=["+LGHF", "xaf", "y+l(%)"]
fig.colorbar(frame=["af", "x+lGHF\t[mW/m@+2@+]"],
         position=f"g{str(afr_lon_max+4)}/{str(afr_lat_min+1)}+w15c/0.5c+v+e")



fig.legend(position="g26/28+w4.6/1.7", box='+gwhite', transparency=30)


fig.show(width=800)

fig.savefig(DIR/'fig'/"fig_s8.pdf", dpi=300 )
fig.savefig(DIR/'fig'/"fig_s8.jpg", dpi=300 )

# %%
fig = pygmt.Figure()
with fig.subplot(
    nrows=2,
    ncols=2,
    #figsize=("30c", "15c"),  # width of 15 cm, height of 6 cm
    subsize = ("13.8c", "15.3c"),
    autolabel=['A)+o0.3/0.5'],
    margins=["-0.1c", "2.4c"],  # horizontal 0.3 cm and vertical 0.2 cm margins
    #title=model[3:],
    #sharex="bt",  # shared x-axis on the bottom side
    sharey=True,  # shared y-axis on the left side
    #frame="WSrt",
):


           
    with fig.set_panel(panel=[0, 0]):


        cmap = pygmt.makecpt(
            cmap='inferno', #temp 19lev
            series='0/50/10',
            continuous=True,
            reverse=True,)



        fig.basemap(region=region_gmt, projection=projection, frame='WsNe',  panel=[0, 0])

       # GHF plotting
        fig.grdimage(ds_afr_rab['RSD'], 
             #interpolation  = 'n',  dpi='i', 
            )
                #frame=["+LGHF", "xaf", "y+l(%)"]
        fig.colorbar(frame=["af",  "x+lCV\tof\tGHF\t[mW/m@+2@+]"],
           position=f"g{str(afr_lon_min+1)}/{str(afr_lat_min-5)}+w13c/0.5c+h+e")
        
        
        fig.coast(
            projection=projection,
            #shorelines=0.5,
            water="lightblue", 
            shorelines="0.01p,black",
            borders=["1/0.01p,black"],
            lakes="lightblue",
            rivers="lightblue" ,

            #water='white',
            )
        
        

   
    with fig.set_panel(panel=[0, 1] ):
        #####RL

        cmap= pygmt.makecpt(
            cmap='davos', #temp 19lev
            series=f"0/20/1",
            continuous=True,
            reverse=True,
        )

        fig.basemap(region=region_gmt, projection=projection, frame='eNsw',   panel=[0, 1])
        
        fig.plot(x=0, y=0,  projection=projection, cmap=False,
              label='"Residual of GHF"',
                      pen="0.5p", style="c0.21c")
       # GHF plotting
        fig.grdimage(ds_afr_rab['UNC'], 
                     #interpolation  = 'n',  dpi='i', 
                    )



        fig.coast(
            projection=projection,
            #shorelines=0.5,
            water="lightblue", 
            shorelines="0.01p,black",
            borders=["1/0.01p,black"],
            lakes="lightblue",
            rivers="lightblue" ,
            #water='white',
            )

        fig.colorbar(frame=["af",  "x+lUncertainity\tof\tGHF\t[mW/m@+2@+]"],
                 position=f"g{str(afr_lon_max +4)}/{str(afr_lat_min+1)}+w15c/0.5c+v+e") 
        
        cmap= pygmt.makecpt(
                    cmap='vik', #temp 19lev
                    series=f"-30/30/3",
                    continuous=True,
                    reverse=False,
                )


        '''
        fig.plot(x=gt_Afr_ra_lon, y=gt_Afr_ra_lat,   cmap=True, projection=projection,                                
                 color=  resid_ra , label=cmap,
                              pen="1p,black", style="c0.24c")'''
        fig.plot(x=Afr_rab_lon, y=Afr_rab_lat,   cmap=True, projection=projection,                                
                 color=  resid_rab , label=cmap,
                              pen="1p,black", style="c0.24c")      
        '''
        fig.plot(x=lon_hf_extreme_a, y=lat_hf_extreme_a,    projection=projection,                               
                 color=  'green' ,         pen="1p,black", style="t0.24c")
        fig.plot(x=lon_hf_extreme_b, y=lat_hf_extreme_b,    projection=projection,                               
                 color=  'green' ,         pen="1p,black", style="t0.24c")'''

                #frame=["+LGHF", "xaf", "y+l(%)"]
        fig.colorbar(frame=["af",  "x+lResidual\tof\tGHF\t[mW/m@+2@+]"],
                 position=f"g{str(afr_lon_min+1)}/{str(afr_lat_min-5)}+w13c/0.5c+h+e")
        
        fig.legend(position="g-15/-10", box=False)

fig.show(width=800)

fig.savefig(DIR/'fig'/"fig_7.pdf", dpi=300 )
fig.savefig(DIR/'fig'/"fig_7.jpg", dpi=300 )

# %%
def add_identity(axes, *line_args, **line_kwargs):
    identity, = axes.plot([], [], *line_args, **line_kwargs)
    def callback(axes):
        low_x, high_x = axes.get_xlim()
        low_y, high_y = axes.get_ylim()
        low = max(low_x, low_y)
        high = min(high_x, high_y)
        identity.set_data([low, high], [low, high])
    callback(axes)
    axes.callbacks.connect('xlim_changed', callback)
    axes.callbacks.connect('ylim_changed', callback)
    return axes


hq_lower_bound = 0

font_size = 30

point_size = 150



KPI_df = pd.DataFrame()

#define plotting region (2 rows, 2 columns)
fig, axes = plt.subplots(1, 2, figsize=(32,15), dpi=300)

# Seaborn setting                                                                                                                                              
#sns.set(style='white',  font_scale = 3)

sns.set(style='white',  font_scale = 3.5)
#parameters = {'axes.best_n_featuressize': 35,
#          'axes.titlesize': 35}
#plt.rcParams.update(parameters)

#####
errors      = abs(y_test_rab - y_pred_rab)
errors      = abs(y_test_rab - y_pred_rab)
mape        = round( mean_absolute_percentage_error(y_test_rab, y_pred_rab), 2) 
accuracy    = round(100 - mape *100, 3)
mae         = round(mean_absolute_error(y_test_rab, y_pred_rab ), 1)
rmse        = round(mean_squared_error(y_test_rab, y_pred_rab , squared=False), 1)
nrmse       = round( rmse/(y_test_rab.mean()) , 2) 
r2          = round(r2_score(y_test_rab, y_pred_rab ), 2)
ev          = round( explained_variance_score(y_test_rab, y_pred_rab), 3)
mnae        = round( median_absolute_error(y_test_rab, y_pred_rab), 3) 
mpe         =  round(np.mean((y_test_rab -y_pred_rab)/y_test_rab) , 3)
ccc         = round(concordance_correlation_coefficient(y_test_rab, y_pred_rab),2)
bias        = round(y_pred_rab.mean() - y_test_rab.mean(), 2)
max_e       = round( max_error(y_test_rab, y_pred_rab), 0)
min_e       = round( errors.min(), 3)
Max         = round(y_pred_rab.max(), 0)
Min         = round(y_pred_rab.min(), 0)

rsd         = round(np.std(y_pred_rab) / np.mean(y_pred_rab) ,3)

rmse_rl     = round(mean_squared_error(y_test_rab, y_pred_rab , squared=False), 1)
max_e       = round( max_error(y_test_rab, y_pred_rab), 0)
min_e       = round( errors.min(), 3)
Max         = round(y_pred_rab.max(), 0)
Min         = round(y_pred_rab.min(), 0)

KPI_df.loc['NRMSE', f'RF_{best_n_features}'] = nrmse
KPI_df.loc['RMSE', f'RF_{best_n_features}'] = rmse
KPI_df.loc['MAE', f'RF_{best_n_features}'] = mae
KPI_df.loc['MAPE', f'RF_{best_n_features}'] = mape
KPI_df.loc['CD', f'RF_{best_n_features}'] = r2
KPI_df.loc['EV', f'RF_{best_n_features}'] = ev
KPI_df.loc['MAX_E', f'RF_{best_n_features}'] = max_e
KPI_df.loc['MIN_E', f'RF_{best_n_features}'] = min_e
KPI_df.loc['MedAE', f'RF_{best_n_features}'] = mnae
KPI_df.loc['MPE', f'RF_{best_n_features}'] = mpe
KPI_df.loc['ACC', f'RF_{best_n_features}'] = accuracy
KPI_df.loc['MAX', f'RF_{best_n_features}'] = Max    
KPI_df.loc['RSD', f'RF_{best_n_features}'] = rsd
KPI_df.loc['CCC', f'RF_{best_n_features}'] = ccc
KPI_df.loc['BIAS', f'RF_{best_n_features}'] = bias

KPI_df.loc['RI', f'RF_{best_n_features}'] = (rmse_rl - rmse)/rmse_rl * 100


sns.regplot(x=y_pred_rab, y=y_test_rab,    ax= axes[0], 
            line_kws={"color": "r"} , scatter_kws={ "edgecolor":"w", 's':point_size, },
     label=  
     f"""     
     $NRMSe$ :   {nrmse} 
     $R^2$         :   {r2}
     $MPe$      :  {mpe}
     """)


'''sns.scatterplot(x=y_pred_rab[mask],y=y_test_rab[mask], color="red", 
                s=point_size,  ax= axes[0], edgecolor="white", 
               #best_n_features= "Mae > 15"  
               )'''
axes[0].set(xlabel='$\hat{z}$ [$mW/m^{2}$]',ylabel='$z$ [$mW/m^{2}$]')
axes[0].set_title(f"{sub_figs[0]})   Reference vs predicted values", loc ='left', pad=20,   y=1.1)
axes[0].set_xlim([hq_lower_bound, hq_upper_bound])
axes[0].set_ylim([hq_lower_bound, hq_upper_bound])
#axes[0].set_xticks([0, 25, 50, 75, 100, 125, 150, 160])
axes[0].locator_params(axis='x', nbins=9)
axes[0].locator_params(axis='y', nbins=9)

#bbox_to_anchor=(2, 0), 
axes[0].legend( frameon=False,loc="lower right")
for lh in axes[0].get_legend().legendHandles: 
    lh._sizes = [0] 


    #$R_i$          :  {round((rmse_rl - rmse)/rmse_rl,3)}
add_identity(axes[0], color='grey', ls='--')
#mn = min(plt.gca().axis()) and mx = max(plt.gca().axis())

####
mean= "$\overline{\hat{z}}$"
median= "$\widetilde{\hat{z}}$"
std= "$s_{\hat{z}}$"

sns.kdeplot(y_pred_rab,  ax =axes[1],fill=True, 
            color="orange", label=f'''
{mean} : {round(y_pred_rab.mean(),1)}
{median} : {round(np.median(y_pred_rab),1)}
{std} : {round(y_pred_rab.std(),1)}
                            ''')
#axes[1].axvline(x=y_pred_rab.mean() , c='b')


          
#axes[1].axvline(x=y_pred_rab.mean() , c='g')

mean_t = "$\overline{z}$"
median_t = "$\widetilde{z}$"
std_t = "$s_{z}$"

sns.kdeplot(y_test_rab,  ax =axes[1],fill=True, 
            color="b", label=f'''
{mean_t}  : {round(y_test_rab.mean(),1)}
{median_t}  : {round(np.median(y_test_rab),1)}
{std_t} : {round(y_test_rab.std(),1)}
                            ''')
#axes[1].axvline(x=y_test_rab.mean() , c='r')

axes[1].legend( frameon=False, bbox_to_anchor=(1.15, 1.08))
axes[1].set_yticks([]) 

axes[1].set(xlabel='GHF [$mW/m^{2}$]',ylabel='PDF' )

axes[1].set_title(f'{sub_figs[1]})   Density Plots', loc ='left', pad=20,   y=1.1)
#axes[1].set_xticks([0, 25, 50, 75, 100, 125, 150, 160])

axes[1].set_xlim([hq_lower_bound, hq_upper_bound])

axes[1].locator_params(axis='x', nbins=9)
###
     

plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0, hspace=0)
plt.tight_layout()

fig.savefig(DIR/'fig'/"fig_6.pdf", bbox_inches='tight', dpi=300 )
fig.savefig(DIR/'fig'/"fig_6.jpg", bbox_inches='tight', dpi=300 )

# %%
def add_identity(axes, *line_args, **line_kwargs):
    identity, = axes.plot([], [], *line_args, **line_kwargs)
    def callback(axes):
        low_x, high_x = axes.get_xlim()
        low_y, high_y = axes.get_ylim()
        low = max(low_x, low_y)
        high = min(high_x, high_y)
        identity.set_data([low, high], [low, high])
    callback(axes)
    axes.callbacks.connect('xlim_changed', callback)
    axes.callbacks.connect('ylim_changed', callback)
    return axes




font_size = 30

point_size = 150



KPI_df = pd.DataFrame()

#define plotting region (2 rows, 2 columns)
fig, axes = plt.subplots(1, 2, figsize=(32,15), dpi=300)

# Seaborn setting                                                                                                                                              
#sns.set(style='white',  font_scale = 3)

sns.set(style='white',  font_scale = 3.5)
#parameters = {'axes.best_n_featuressize': 35,
#          'axes.titlesize': 35}
#plt.rcParams.update(parameters)

#####
errors      = abs(y_test_NOD_rab - y_pred_NOD_rab)
errors      = abs(y_test_NOD_rab - y_pred_NOD_rab)
mape        = round( mean_absolute_percentage_error(y_test_NOD_rab, y_pred_NOD_rab), 2) 
accuracy    = round(100 - mape *100, 3)
mae         = round(mean_absolute_error(y_test_NOD_rab, y_pred_NOD_rab ), 1)
rmse        = round(mean_squared_error(y_test_NOD_rab, y_pred_NOD_rab , squared=False), 1)
nrmse       = round( rmse/(y_test_NOD_rab.mean()) , 2) 
r2          = round(r2_score(y_test_NOD_rab, y_pred_NOD_rab ), 2)
ev          = round( explained_variance_score(y_test_NOD_rab, y_pred_NOD_rab), 3)
mnae        = round( median_absolute_error(y_test_NOD_rab, y_pred_NOD_rab), 3) 
mpe         =  round(np.mean((y_test_NOD_rab -y_pred_NOD_rab)/y_test_NOD_rab) , 3)
ccc         = round(concordance_correlation_coefficient(y_test_NOD_rab, y_pred_NOD_rab),2)
bias        = round(y_pred_NOD_rab.mean() - y_test_NOD_rab.mean(), 2)
max_e       = round( max_error(y_test_NOD_rab, y_pred_NOD_rab), 0)
min_e       = round( errors.min(), 3)
Max         = round(y_pred_NOD_rab.max(), 0)
Min         = round(y_pred_NOD_rab.min(), 0)

rsd         = round(np.std(y_pred_NOD_rab) / np.mean(y_pred_NOD_rab) ,3)

rmse_rl     = round(mean_squared_error(y_test_NOD_rab, y_pred_NOD_rab , squared=False), 1)
max_e       = round( max_error(y_test_NOD_rab, y_pred_NOD_rab), 0)
min_e       = round( errors.min(), 3)
Max         = round(y_pred_NOD_rab.max(), 0)
Min         = round(y_pred_NOD_rab.min(), 0)

KPI_df.loc['NRMSE', f'RF_{best_n_features}'] = nrmse
KPI_df.loc['RMSE', f'RF_{best_n_features}'] = rmse
KPI_df.loc['MAE', f'RF_{best_n_features}'] = mae
KPI_df.loc['MAPE', f'RF_{best_n_features}'] = mape
KPI_df.loc['CD', f'RF_{best_n_features}'] = r2
KPI_df.loc['EV', f'RF_{best_n_features}'] = ev
KPI_df.loc['MAX_E', f'RF_{best_n_features}'] = max_e
KPI_df.loc['MIN_E', f'RF_{best_n_features}'] = min_e
KPI_df.loc['MedAE', f'RF_{best_n_features}'] = mnae
KPI_df.loc['MPE', f'RF_{best_n_features}'] = mpe
KPI_df.loc['ACC', f'RF_{best_n_features}'] = accuracy
KPI_df.loc['MAX', f'RF_{best_n_features}'] = Max    
KPI_df.loc['RSD', f'RF_{best_n_features}'] = rsd
KPI_df.loc['CCC', f'RF_{best_n_features}'] = ccc
KPI_df.loc['BIAS', f'RF_{best_n_features}'] = bias

KPI_df.loc['RI', f'RF_{best_n_features}'] = (rmse_rl - rmse)/rmse_rl * 100


sns.regplot(x=y_pred_NOD_rab, y=y_test_NOD_rab,    ax= axes[0], 
            line_kws={"color": "r"} , scatter_kws={ "edgecolor":"w", 's':point_size, },
     label=  
     f"""     
     $NRMSe$ :   {nrmse} 
     $R^2$         :   {r2}
     $MPe$      :  {mpe}
     """)


'''sns.scatterplot(x=y_pred_NOD_rab[mask],y=y_test_NOD_rab[mask], color="red", 
                s=point_size,  ax= axes[0], edgecolor="white", 
               #best_n_features= "Mae > 15"  
               )'''
axes[0].set(xlabel='$\hat{z}$ [$mW/m^{2}$]',ylabel='$z$ [$mW/m^{2}$]')
axes[0].set_title(f"{sub_figs[0]})   Reference vs predicted values", loc ='left', pad=20,   y=1.1)
axes[0].set_xlim([hq_lower_bound, hq_upper_bound])
axes[0].set_ylim([hq_lower_bound, hq_upper_bound])
#axes[0].set_xticks([0, 25, 50, 75, 100, 125, 150, 160])
axes[0].locator_params(axis='x', nbins=9)
axes[0].locator_params(axis='y', nbins=9)

#bbox_to_anchor=(2, 0), 
axes[0].legend( frameon=False,loc="lower right")
for lh in axes[0].get_legend().legendHandles: 
    lh._sizes = [0] 


    #$R_i$          :  {round((rmse_rl - rmse)/rmse_rl,3)}
add_identity(axes[0], color='grey', ls='--')
#mn = min(plt.gca().axis()) and mx = max(plt.gca().axis())

####
mean= "$\overline{\hat{z}}$"
median= "$\widetilde{\hat{z}}$"
std= "$s_{\hat{z}}$"

sns.kdeplot(y_pred_NOD_rab,  ax =axes[1],fill=True, 
            color="orange", label=f'''
{mean} : {round(y_pred_NOD_rab.mean(),1)}
{median} : {round(np.median(y_pred_NOD_rab),1)}
{std} : {round(y_pred_NOD_rab.std(),1)}
                            ''')
#axes[1].axvline(x=y_pred_NOD_rab.mean() , c='b')


          
#axes[1].axvline(x=y_pred_NOD_rab.mean() , c='g')

mean_t = "$\overline{z}$"
median_t = "$\widetilde{z}$"
std_t = "$s_{z}$"

sns.kdeplot(y_test_NOD_rab,  ax =axes[1],fill=True, 
            color="b", label=f'''
{mean_t}  : {round(y_test_NOD_rab.mean(),1)}
{median_t}  : {round(np.median(y_test_NOD_rab),1)}
{std_t} : {round(y_test_NOD_rab.std(),1)}
                            ''')
#axes[1].axvline(x=y_test_NOD_rab.mean() , c='r')

axes[1].legend( frameon=False, bbox_to_anchor=(1.15, 1.08))
axes[1].set_yticks([]) 

axes[1].set(xlabel='GHF [$mW/m^{2}$]',ylabel='PDF' )

axes[1].set_title(f'{sub_figs[1]})   Density Plots', loc ='left', pad=20,   y=1.1)
#axes[1].set_xticks([0, 25, 50, 75, 100, 125, 150, 160])

axes[1].set_xlim([hq_lower_bound, hq_upper_bound])

axes[1].locator_params(axis='x', nbins=9)
###
     

plt.subplots_adjust(left=0, bottom=0, right=1, top=1, wspace=0, hspace=0)
plt.tight_layout()

#fig.savefig(DIR/'fig'/"fig_6.pdf", bbox_inches='tight', dpi=300 )
#fig.savefig(DIR/'fig'/"fig_6.jpg", bbox_inches='tight', dpi=300 )

# %%
fig = pygmt.Figure()
with fig.subplot(
    nrows=4,
    ncols=2,
    #figsize=("30c", "15c"),  # width of 15 cm, height of 6 cm
    subsize = ("13.5c", "13.5c"),
    autolabel=['A)+o0.3/-1.2'],
    margins=["0.18c", "1c"],  # horizontal 0.3 cm and vertical 0.2 cm margins
    #title=model[3:],
    sharex="b",  # shared x-axis on the bottom side
    sharey=True,  # shared y-axis on the left side
    frame="lrtb",
):


    #####Kriging
    with fig.set_panel(panel=[0, 0]):




        fig.basemap(region=region_gmt, projection=projection, frame='WNse', panel=[0, 0])

       
        fig.grdimage(
             grid=ds_afr_ra['RFE_04'], # xarray.DataArray containing VSV values
             region=region_gmt,
             projection=projection,
                 cmap=cmap_ghf,
              #interpolation  = 'n',  dpi='i', 

        )
                #frame=["+LGHF", "xaf", "y+l(%)"]
        fig.colorbar(frame=["af",  "x+lGHF\t[mW/m@+2@+]"],
                     position=f"g{str(afr_lon_min+2)}/{str(afr_lat_min-6)}+w12c/0.5c+h+e")
        
        


        fig.coast(
            projection=projection,
            #shorelines=0.5,
            water="lightblue", shorelines="1p,black",
            borders=["1/0.2p,black"],
            #water='white',
            #dcw="=AS,=EU+gdarkgrey",
            #resolution = 'i',
            )


   
    with fig.set_panel(panel=[0, 1] ):
        #####RL

        cmap= pygmt.makecpt(
            cmap='broc', #temp 19lev
            series=f"-20/20/1",
            continuous=True,
            reverse=False,
        )

        fig.basemap(region=region_gmt, projection=projection, frame='ENsw',  panel=[0, 1])


        fig.grdimage(
             grid=ds_afr_ra['Q_Diff_11_04'], # xarray.DataArray containing VSV values
             region=region_gmt,
             projection=projection,
                 cmap=cmap,
              #interpolation  = 'n',  dpi='i', 

        )



        fig.coast(
            projection=projection,
            #shorelines=0.5,
            water="lightblue", 
            shorelines="0.01p,black",
            borders=["1/0.01p,black"],
            lakes="lightblue",
            rivers="lightblue" ,
            #water='white',
            #dcw="=AS,=EU+gdarkgrey",
            #resolution = 'i',
            )


 

        fig.colorbar(frame=["af",  "x+lGHF\t[mW/m@+2@+]"],
                     position=f"g{str(afr_lon_min+2)}/{str(afr_lat_min-6)}+w12c/0.5c+h+e")
    

    with fig.set_panel(panel=[1, 0]):




        fig.basemap(region=region_gmt, projection=projection,  panel=[1, 0])

        fig.grdimage(
             grid=ds_afr_ra['RFE_09'], # xarray.DataArray containing VSV values
             region=region_gmt,
             projection=projection,
                 cmap=cmap_ghf,
              #interpolation  = 'n',  dpi='i', 

        )

                #frame=["+LGHF", "xaf", "y+l(%)"]
        fig.colorbar(frame=["af",  "x+lGHF\t[mW/m@+2@+]"],
                     position=f"g{str(afr_lon_min+2)}/{str(afr_lat_min-6)}+w12c/0.5c+h+e")
        
        


        fig.coast(
            projection=projection,
            #shorelines=0.5,
            water="lightblue", 
            shorelines="0.01p,black",
            borders=["1/0.01p,black"],
            lakes="lightblue",
            rivers="lightblue" ,
            #water='white',
            #dcw="=AS,=EU+gdarkgrey",
            #resolution = 'i',
            )


   
    with fig.set_panel(panel=[1, 1] ):
        #####RL

        cmap= pygmt.makecpt(
            cmap='broc', #temp 19lev
            series=f"-20/20/1",
            continuous=True,
            reverse=False,
        )


        fig.basemap(region=region_gmt, projection=projection,   panel=[1, 1])


        fig.grdimage(
             grid=ds_afr_ra['Q_Diff_11_09'], # xarray.DataArray containing VSV values
             region=region_gmt,
             projection=projection,
                 cmap=cmap,
              #interpolation  = 'n',  dpi='i', 

        )




        fig.coast(
            projection=projection,
            #shorelines=0.5,
            water="lightblue", 
            shorelines="0.01p,black",
            borders=["1/0.01p,black"],
            lakes="lightblue",
            rivers="lightblue" ,
            #water='white',
            #dcw="=AS,=EU+gdarkgrey",
            #resolution = 'i',
            )


 

        fig.colorbar(frame=["af",  "x+lGHF\t[mW/m@+2@+]"],
                     position=f"g{str(afr_lon_min+2)}/{str(afr_lat_min-6)}+w12c/0.5c+h+e")
            
    with fig.set_panel(panel=[2, 0]):



        fig.basemap(region=region_gmt, projection=projection, frame='WSne',  panel=[2, 0])

        fig.grdimage(
             grid=ds_afr_ra['RFE_16'], # xarray.DataArray containing VSV values
             region=region_gmt,
             projection=projection,
                 cmap=cmap_ghf,
              #interpolation  = 'n',  dpi='i', 

        )

                #frame=["+LGHF", "xaf", "y+l(%)"]
        fig.colorbar(frame=["af",  "x+lGHF\t[mW/m@+2@+]"],
                     position=f"g{str(afr_lon_min-2)}/{str(afr_lat_min-8)}+w13c/0.5c+h+e")
        
        


        fig.coast(
            projection=projection,
            #shorelines=0.5,
            water="lightblue", 
            shorelines="0.01p,black",
            borders=["1/0.01p,black"],
            lakes="lightblue",
            rivers="lightblue" ,
            #water='white',
            #dcw="=AS,=EU+gdarkgrey",
            #resolution = 'i',
            )


   
    with fig.set_panel(panel=[2, 1] ):
        #####RL

        cmap= pygmt.makecpt(
            cmap='broc', #temp 19lev
            series=f"-20/20/1",
            continuous=True,
            reverse=False,
        )


        fig.basemap(region=region_gmt, projection=projection, frame='ESnw',  panel=[2, 1])


        fig.grdimage(
             grid=ds_afr_ra['Q_Diff_11_16'], # xarray.DataArray containing VSV values
             region=region_gmt,
             projection=projection,
                 cmap=cmap,
              #interpolation  = 'n',  dpi='i', 

        )




        fig.coast(
            projection=projection,
            #shorelines=0.5,
            water="lightblue", 
            shorelines="0.01p,black",
            borders=["1/0.01p,black"],
            lakes="lightblue",
            rivers="lightblue" ,
            #water='white',
            #dcw="=AS,=EU+gdarkgrey",
            #resolution = 'i',
            )


 

        fig.colorbar(frame=["af",  "x+lGHF\t[mW/m@+2@+]"],
                     position=f"g{str(afr_lon_min-2)}/{str(afr_lat_min-8)}+w13c/0.5c+h+e")
            

fig.show(width=800)

fig.savefig(DIR/'fig'/"fig_s5.pdf", dpi=300 )
fig.savefig(DIR/'fig'/"fig_s5.jpg", dpi=300 )

# %%
fig = pygmt.Figure()
with fig.subplot(
    nrows=4,
    ncols=2,
    #figsize=("30c", "15c"),  # width of 15 cm, height of 6 cm
    subsize = ("13.5c", "13.5c"),
    autolabel=['A)+o0.3/-1.2'],
    margins=["0.18c", "1c"],  # horizontal 0.3 cm and vertical 0.2 cm margins
    #title=model[3:],
    sharex="b",  # shared x-axis on the bottom side
    sharey=True,  # shared y-axis on the left side
    frame="lrtb",
):


    #####Kriging
    with fig.set_panel(panel=[0, 0]):




        fig.basemap(region=region_gmt, projection=projection, frame='WNse', panel=[0, 0])

       
        fig.grdimage(
             grid=ds_afr_rab['RFE_04'], # xarray.DataArray containing VSV values
             region=region_gmt,
             projection=projection,
                 cmap=cmap_ghf,
             #interpolation  = 'n',  dpi='i', 

        )
                #frame=["+LGHF", "xaf", "y+l(%)"]
        fig.colorbar(frame=["af",  "x+lGHF\t[mW/m@+2@+]"],
                     position=f"g{str(afr_lon_min+2)}/{str(afr_lat_min-6)}+w12c/0.5c+h+e")
        
        


        fig.coast(
            projection=projection,
            #shorelines=0.5,
            water="lightblue", shorelines="1p,black",
            borders=["1/0.2p,black"],
            #water='white',
            #dcw="=AS,=EU+gdarkgrey",
            #resolution = 'i',
            )


   
    with fig.set_panel(panel=[0, 1] ):
        #####RL

        cmap= pygmt.makecpt(
            cmap='broc', #temp 19lev
            series=f"-20/20/1",
            continuous=True,
            reverse=False,
        )

        fig.basemap(region=region_gmt, projection=projection, frame='ENsw',  panel=[0, 1])


        fig.grdimage(
             grid=ds_afr_rab['Q_Diff_11_04'], # xarray.DataArray containing VSV values
             region=region_gmt,
             projection=projection,
                 cmap=cmap,
             #interpolation  = 'n',  dpi='i', 

        )



        fig.coast(
            projection=projection,
            #shorelines=0.5,
            water="lightblue", 
            shorelines="0.01p,black",
            borders=["1/0.01p,black"],
            lakes="lightblue",
            rivers="lightblue" ,
            #water='white',
            #dcw="=AS,=EU+gdarkgrey",
            #resolution = 'i',
            )


 

        fig.colorbar(frame=["af",  "x+lGHF\t[mW/m@+2@+]"],
                     position=f"g{str(afr_lon_min+2)}/{str(afr_lat_min-6)}+w12c/0.5c+h+e")
    

    with fig.set_panel(panel=[1, 0]):




        fig.basemap(region=region_gmt, projection=projection,  panel=[1, 0])

        fig.grdimage(
             grid=ds_afr_rab['RFE_09'], # xarray.DataArray containing VSV values
             region=region_gmt,
             projection=projection,
                 cmap=cmap_ghf,
             #interpolation  = 'n',  dpi='i', 

        )

                #frame=["+LGHF", "xaf", "y+l(%)"]
        fig.colorbar(frame=["af",  "x+lGHF\t[mW/m@+2@+]"],
                     position=f"g{str(afr_lon_min+2)}/{str(afr_lat_min-6)}+w12c/0.5c+h+e")
        
        


        fig.coast(
            projection=projection,
            #shorelines=0.5,
            water="lightblue", 
            shorelines="0.01p,black",
            borders=["1/0.01p,black"],
            lakes="lightblue",
            rivers="lightblue" ,
            #water='white',
            #dcw="=AS,=EU+gdarkgrey",
            #resolution = 'i',
            )


   
    with fig.set_panel(panel=[1, 1] ):
        #####RL

        cmap= pygmt.makecpt(
            cmap='broc', #temp 19lev
            series=f"-20/20/1",
            continuous=True,
            reverse=False,
        )


        fig.basemap(region=region_gmt, projection=projection,   panel=[1, 1])


        fig.grdimage(
             grid=ds_afr_rab['Q_Diff_11_09'], # xarray.DataArray containing VSV values
             region=region_gmt,
             projection=projection,
                 cmap=cmap,
             #interpolation  = 'n',  dpi='i', 

        )




        fig.coast(
            projection=projection,
            #shorelines=0.5,
            water="lightblue", 
            shorelines="0.01p,black",
            borders=["1/0.01p,black"],
            lakes="lightblue",
            rivers="lightblue" ,
            #water='white',
            #dcw="=AS,=EU+gdarkgrey",
            #resolution = 'i',
            )


 

        fig.colorbar(frame=["af",  "x+lGHF\t[mW/m@+2@+]"],
                     position=f"g{str(afr_lon_min+2)}/{str(afr_lat_min-6)}+w12c/0.5c+h+e")
            
    with fig.set_panel(panel=[2, 0]):





        fig.basemap(region=region_gmt, projection=projection, frame='WSne',  panel=[2, 0])

        fig.grdimage(
             grid=ds_afr_rab['RFE_16'], # xarray.DataArray containing VSV values
             region=region_gmt,
             projection=projection,
                 cmap=cmap_ghf,
             #interpolation  = 'n',  dpi='i', 

        )

                #frame=["+LGHF", "xaf", "y+l(%)"]
        fig.colorbar(frame=["af",  "x+lGHF\t[mW/m@+2@+]"],
                     position=f"g{str(afr_lon_min-2)}/{str(afr_lat_min-8)}+w13c/0.5c+h+e")
        
        


        fig.coast(
            projection=projection,
            #shorelines=0.5,
            water="lightblue", 
            shorelines="0.01p,black",
            borders=["1/0.01p,black"],
            lakes="lightblue",
            rivers="lightblue" ,
            #water='white',
            #dcw="=AS,=EU+gdarkgrey",
            #resolution = 'i',
            )


   
    with fig.set_panel(panel=[2, 1] ):
        #####RL

        cmap= pygmt.makecpt(
            cmap='broc', #temp 19lev
            series=f"-20/20/1",
            continuous=True,
            reverse=False,
        )


        fig.basemap(region=region_gmt, projection=projection, frame='ESnw',  panel=[2, 1])


        fig.grdimage(
             grid=ds_afr_rab['Q_Diff_11_16'], # xarray.DataArray containing VSV values
             region=region_gmt,
             projection=projection,
                 cmap=cmap,
             #interpolation  = 'n',  dpi='i', 

        )




        fig.coast(
            projection=projection,
            #shorelines=0.5,
            water="lightblue", 
            shorelines="0.01p,black",
            borders=["1/0.01p,black"],
            lakes="lightblue",
            rivers="lightblue" ,
            #water='white',
            #dcw="=AS,=EU+gdarkgrey",
            #resolution = 'i',
            )


 

        fig.colorbar(frame=["af",  "x+lGHF\t[mW/m@+2@+]"],
                     position=f"g{str(afr_lon_min-2)}/{str(afr_lat_min-8)}+w13c/0.5c+h+e")
            

fig.show(width=800)

fig.savefig(DIR/'fig'/"fig_s6.pdf", dpi=300 )
fig.savefig(DIR/'fig'/"fig_s6.jpg", dpi=300 )
